# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clone()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext spacy
# !python -m spacy download en
# !python -m spacy download es
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Requirement already satisfied: torchtext in /usr/local/lib/python3.6/dist-packages (0.3.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.18.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.6.0+cu101)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.8.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (50.3.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchtext) (0.16.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.2.0)
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (50.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.18.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.2.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Requirement already satisfied: es_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.2.5/es_core_news_sm-2.2.5.tar.gz#egg=es_core_news_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from es_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.0.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.18.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (4.41.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (50.3.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.2.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# --2020-10-23 14:46:23--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.09s
#
# 2020-10-23 14:46:23 (86.9 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2020-10-23 14:46:23--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.1s
#
# 2020-10-23 14:46:23 (72.1 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# #Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ##Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'
    print_size = False
    if print_size:
      print(query.size())
      print(key.size())
      print(value.size())
    
    # scores = QK^T/scale
    scale = key.size()[-1]
    scores = torch.bmm(query, key.permute(0, 2, 1))
    scores = scores / math.sqrt(scale)

    if print_size:
      print(scores.size())
      print(mask.size())
    
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
        
    # output = softmax(scores)(V)
    output = torch.matmul(F.softmax(scores, dim=2), value)
    
    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        
        # Make an attention head (linear layers for q, k, and v)
        
        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.head_weights = clones(nn.Linear(d_model, d_model), h)
        
        # etc.

    def forward(self, query, key, value, mask):
        # For each attention head
            # Pass the query, key, value through their respective layers
            # Compute scaled dot-product attention on the output
        # etc.
        return attention(self.head_weights[0](query), self.head_weights[1](key), self.head_weights[2](value), mask)

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es')
spacy_en = spacy.load('en')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
spanish_text = open('./spanish','r')
english_text = open('./english', 'r')
english_lines = list(english_text)
spanish_lines = list(spanish_text)

fields = (["src", SRC], ["trg", TGT])
examples = [torchtext.data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = torchtext.data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ##Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	de Jesús
# Translation:	Jesus of Jesus of Christ
# Target:		See what God hath done .
#
# Spanish:	Octubre de 2016
# Translation:	October 2016
# Target:		October 2016
#
# Spanish:	Moisés 1:39 .
# Translation:	Moses 1:39 .
# Target:		Moses 1:39 .
#
# Spanish:	Guíenme , <unk>
# Translation:	Lead ,
# Target:		Lead me , guide me , walk beside me ,
#
# Spanish:	Familias bajo el convenio
# Translation:	Families under the covenant covenant covenant of Families
# Target:		Families under Covenant
#
# Spanish:	Véase Mosíah 2:22 .
# Translation:	See Mosiah 18:9 .
# Target:		See Mosiah 2:22 .
#
# Spanish:	Por Linda K. Burton
# Translation:	By Linda K. Burton
# Target:		By Linda K. Burton
#
# Spanish:	Sentí paz ” .
# Translation:	I felt peace . ”
# Target:		I had peace . ”
#
# Spanish:	Tienen cinco hijos .
# Translation:	They are the children of the children of the parents of the parents of the parents of the parents of the parents of the parents of the parents of the parents of the parents of the parents of the parents of the parents of the parents of the children of the children are .
# Target:		They are the parents of five children .
#
# Spanish:	1º de abril de 2017
# Translation:	October 1 , 2017
# Target:		April 01 , 2017
#
# Spanish:	Tercero : Expresar compasión .
# Translation:	Third , serving compassion .
# Target:		Third — express compassion .
#
# Spanish:	Véase 1 Nefi 8 .
# Translation:	See 1 Nephi 8 .
# Target:		See 1 Nephi 8 .
#
# Spanish:	Sigan al Varón de Galilea
# Translation:	Follow the end of the Messiah of Galilee ,
# Target:		Follow the Man of Galilee
#
# Spanish:	Comencemos con ser caritativos .
# Translation:	Let us begin with charitable .
# Target:		Let ’s begin with becoming charitable .
#
# Spanish:	Lema de la Mutual para 2016
# Translation:	“ the Mutual to 2016
# Target:		2016 Mutual theme
#
# Spanish:	Por el élder L. Tom Perry
# Translation:	By Elder L. Tom Perry
# Target:		By Elder L. Tom Perry
#
# Spanish:	Por el élder Allan F. Packer
# Translation:	By Elder Packer
# Target:		By Elder Allan F. Packer
#
# Spanish:	1 Corintios 15:51–55 , 57 .
# Translation:	1 Corinthians 15:20–22 , 57 .
# Target:		1 Corinthians 15:51–55 , 57 .
#
# Spanish:	Véase Doctrina y Convenios 68:25–28 .
# Translation:	See Doctrine and Covenants 45:26 .
# Target:		See Doctrine and Covenants 68:25–28 .
#
# Spanish:	¿ Dónde están las llaves ?
# Translation:	Where are the keys ?
# Target:		“ Where are the keys ? ”
#
# Spanish:	<unk> 11:1 ; Alma 32:21 .
# Translation:	We will be able to get up .
# Target:		See Hebrews 11:1 ; Alma 32:21 .
#
# Spanish:	Coro : " Divino Redentor "
# Translation:	" The Redeemer "
# Target:		Choir ( without announcement ) : " O Divine Redeemer "
#
# Spanish:	Entonces , ¿ por qué obedecer ?
# Translation:	Then , why do we obey ?
# Target:		Why Then Obey ?
#
# Spanish:	La función importante de los ángeles .
# Translation:	The role of angels .
# Target:		The important role of angels .
#
# Spanish:	<unk> al mundo para la Segunda Venida
# Translation:	We are to be the Second Coming to the world
# Target:		Preparing the World for the Second Coming
#
# Spanish:	La manera de hacerlo es clara .
# Translation:	The way is to do it is clear .
# Target:		The way to do that is clear .
#
# Spanish:	Él es el Salvador del mundo .
# Translation:	He is the Savior of the world .
# Target:		He is the Savior of the world .
#
# Spanish:	Observé un comportamiento diferente en mis padres
# Translation:	I watched a different behavior in my parents
# Target:		I noticed different behavior on the part of my parents .
#
# Spanish:	La familia de la hermana Uchtdorf con misioneros
# Translation:	Sister Uchtdorf ’s family with missionaries
# Target:		Sister Uchtdorf ’s family with missionaries
#
# Spanish:	La prueba de la grandeza es la manera
# Translation:	The test of the greatness of the Church is the way of the greatness of the greatness of the Church is the way .
# Target:		The test of greatness is the way
#
# Spanish:	Fue una época muy difícil para ambos .
# Translation:	It was a very difficult time for both .
# Target:		It was a difficult time for them .
#
# Spanish:	Nosotros no determinamos los llamamientos que recibimos .
# Translation:	We do not determine our callings .
# Target:		We do not determine the callings we receive .
#
# Spanish:	Tenemos una responsabilidad y una gran oportunidad .
# Translation:	We have a responsibility and a great opportunity to be a great responsibility .
# Target:		We have a responsibility and a great opportunity .
#
# Spanish:	Además , continuarían <unk> <unk> a Agnes .
# Translation:	In addition , they would be able to bear up .
# Target:		They would also continue to make <unk> to Agnes .
#
# Spanish:	Génesis 2:18 , nota al pie de página b.
# Translation:	Genesis 2:18 , footnote b.
# Target:		Genesis 2:18 , footnote b.
#
# Spanish:	La gente que nos rodea no es perfecta .
# Translation:	The people around us is not perfect .
# Target:		The people around us are not perfect .
#
# Spanish:	Blankenhorn , Fatherless America , págs . 25–26 .
# Translation:	Blankenhorn , Fatherless America , 129 .
# Target:		Blankenhorn , Fatherless America , 25 , 26 .
#
# Spanish:	no tenían dinero y estaban entre gente extraña .
# Translation:	They had no money and the people were not before money .
# Target:		They had no money and were among strangers .
#
# Spanish:	Para protegerlo de daños , percibe el dolor .
# Translation:	To go to the damage , the pain .
# Target:		To protect it from harm , it <unk> pain .
#
# Spanish:	Y , sin demora , vuélvanse al Señor .
# Translation:	And without it is to be opened to the Lord .
# Target:		And , without delay , turn to the Lord .
#
# Spanish:	Su Hijo Jesucristo es nuestro Salvador y Redentor .
# Translation:	His Son , Jesus Christ , and Redeemer .
# Target:		His Son , Jesus Christ , is our Savior and Redeemer .
#
# Spanish:	Que la paz les acompañe hoy y siempre .
# Translation:	May the peace you may always be with you .
# Target:		Until we meet again , may peace be with you … this day and always .
#
# Spanish:	Todos , menos Sailor , murieron en el accidente .
# Translation:	Everyone , they were married in the accident .
# Target:		Her <unk> was broken in the crash .
#
# Spanish:	Las personas a quienes presten servicio sentirán su amor .
# Translation:	People who are serving others will feel love .
# Target:		The people they serve will feel their love .
#
# Spanish:	El Señor las bendecirá con éxito por sus esfuerzos .
# Translation:	The Lord will bless you with success in your efforts .
# Target:		The Lord will crown your efforts with success .
#
# Spanish:	El criterio humano y las buenas intenciones no bastan .
# Translation:	The human human wickedness and good intentions will not be enough .
# Target:		Human judgment and good intentions will not be enough .
#
# Spanish:	Hizo lo mejor que pudo para quitar la suciedad .
# Translation:	He did the best of the rescue .
# Target:		He did his best to gently wash away the dirt .
#
# Spanish:	Ése era su lema y sabía que era cierto .
# Translation:	This was her and then knew it was true .
# Target:		That was her motto , and she knew it was true .
#
# Spanish:	Pero no debe <unk> a quién pertenece la casa .
# Translation:	But they should not be able to do the house .
# Target:		But there should be no doubt as to whose house it really is .
#
# Spanish:	Para la Fortaleza de la Juventud , págs . 42–43 .
# Translation:	For the Strength of Youth ( booklet , 2009 ) .
# Target:		For the Strength of Youth , 42–43 .
#
# Spanish:	¿ Habéis experimentado este potente cambio en vuestros corazones ? .
# Translation:	Have you experienced this mighty change in your hearts ?
# Target:		Have ye experienced this mighty change in your hearts ?
#
# Spanish:	“ el templo ha cambiado mi vida para siempre ” .
# Translation:	“ The temple has changed my life forever . ”
# Target:		“ The temple has changed my life forever . ”
#
# Spanish:	También los invitamos a que envíen fotografías de esas actividades .
# Translation:	We also invited those who accept these activities .
# Target:		We also invite them to send photos of those activities .
#
# Spanish:	Llegas a ser lo que haces y lo que piensas .
# Translation:	They become what you do you and do so .
# Target:		You become what you do and what you think about .
#
# Spanish:	Recibimos una respuesta cuando reconocemos esta divina fuente de fortaleza .
# Translation:	We recognize a answer when we recognize this divine source of strength .
# Target:		An answer comes when we recognize this divine source of strength .
#
# Spanish:	Estos vastos cambios mundiales sirven a los propósitos de Dios .
# Translation:	These so that the foundation of God .
# Target:		These vast , worldwide changes serve the designs of Almighty God .
#
# Spanish:	El hogar es donde todos podemos aprender y crecer juntos .
# Translation:	The home is where we can learn and grow together .
# Target:		Home is a place where we can all learn and grow together .
#
# Spanish:	‘ No me importa ; no me quedaré aquí ’ .
# Translation:	‘ No matter . I will not be here . ’
# Target:		‘ I do n’t care , I am not going to stay here . ’
#
# Spanish:	Carta de la Primera Presidencia , 23 de febrero de 2001 .
# Translation:	First Presidency letter , 23 , 23 , Feb. 23 , 2001 .
# Target:		First Presidency letter , Feb. 23 , 2001 .
#
# Spanish:	Los hombres y las mujeres desempeñan funciones diferentes pero igualmente valiosas .
# Translation:	Men and women were different roles were — but different — the precious and precious roles .
# Target:		Men and women have different but equally valued roles .
#
# Spanish:	“ El Hijo del Hombre ha descendido debajo de todo ello .
# Translation:	“ The Son of Man has descended below all .
# Target:		“ The Son of Man hath descended below them all .
#
# Spanish:	¿ Qué puede faltar si no es el alma ? ” .
# Translation:	What can not be the soul if it is not the soul ? ”
# Target:		What can be gone if it be not the soul ? ”
#
# Spanish:	El padre rogó a su hijo que <unk> la bendición patriarcal .
# Translation:	The father admonished his son his son , the blessing of patriarchal blessing .
# Target:		The father pleaded with his son to get his patriarchal blessing .
#
# Spanish:	Sé que su afán por mejorar a veces puede parecer abrumador .
# Translation:	I know that their trials may improve , sometimes it can be filled with .
# Target:		I know that your quest to improve may seem overwhelming at times .
#
# Spanish:	<unk> constantemente en rectitud , dedicación y servicio en el sacerdocio .
# Translation:	It is to be in righteousness and service in priesthood service .
# Target:		Let us constantly increase in righteousness , dedication , and priesthood service .
#
# Spanish:	Le seguirá el obispo Dean M. Davies , del Obispado Presidente .
# Translation:	He will be followed by Bishop Dean M. Davies , the Presiding Bishopric .
# Target:		He will be followed by Bishop Dean M. Davies of the Presiding Bishopric .
#
# Spanish:	“ Conmigo quédate , Señor ” , Himnos , Nº 98 .
# Translation:	“ I Stand the Lord , ” Hymns , no . 147 .
# Target:		“ Abide with Me ; ’ Tis Eventide , ” Hymns , no . 165 .
#
# Spanish:	Por lo general , a las mujeres les gusta conversar y reunirse .
# Translation:	By the women of the women , we like to meet and talk .
# Target:		Women generally love to talk and gather !
#
# Spanish:	La bondad es algo potente , en especial en un entorno familiar .
# Translation:	The goodness is something powerful , especially a special family family council .
# Target:		Kindness is powerful , especially in a family setting .
#
# Spanish:	4 . El Libro de Mormón es la clave para la supervivencia espiritual
# Translation:	4 . The Book of Mormon is the key to spiritual survival .
# Target:		4 . The Book of Mormon Is Key to Spiritual Survival
#
# Spanish:	Lucy Meserve Smith , en Hijas en Mi Reino , pág. 42 .
# Translation:	Lucy Meserve Smith , in Daughters in My Kingdom , 42 .
# Target:		Lucy Meserve Smith , in Daughters in My Kingdom , 37 .
#
# Spanish:	¿ Qué significa para ustedes la frase “ ninguna palabra corrompida ” ?
# Translation:	What does it mean to you “ any of any word ? ”
# Target:		What does the phrase “ no corrupt communication ” mean to you ?
#
# Spanish:	Sin embargo , debía enseñar a esos jóvenes <unk> de 15 años .
# Translation:	But they should teach these young men to be 15 years old .
# Target:		Yet he was to teach these young , <unk> 15-year - olds .
#
# Spanish:	Aun así , debe haber habido momentos en que no la veía .
# Translation:	Even so , there must have been times when he did not see .
# Target:		Still , there must have been times when she could not see it .
#
# Spanish:	Quizás no sepan esto , pero el presidente y yo somos gemelos .
# Translation:	They may not know this , but President , we are the same .
# Target:		You might not know this , but President Monson and I are twins .
#
# Spanish:	El modo del Señor es la única forma de tener felicidad perdurable .
# Translation:	The Lord ’s way is the only way to have lasting happiness .
# Target:		The Lord ’s way is the only way for us to experience enduring happiness .
#
# Spanish:	Los principios sobre los cuales se basa definen quiénes somos como pueblo .
# Translation:	The principles of which is based define who we are as individuals .
# Target:		The principles upon which it is based define who we are as a people .
#
# Spanish:	<unk> haciendo algo muy significativo para aumentar la paz en el mundo .
# Translation:	They are doing something very difficult to increase the world in peace .
# Target:		You will be doing something very significant to add to the cumulative peace in the world .
#
# Spanish:	Se sostiene a nuevos Setentas y a una nueva Presidencia General de la Primaria
# Translation:	It is proposed to be new and a General Presidency
# Target:		New Seventies , Primary Presidency Sustained
#
# Spanish:	El modelo ha sido claro y uniforme a lo largo de las épocas .
# Translation:	The pattern has been clear and clear and preserved the throughout the times .
# Target:		The pattern has been clear and consistent throughout the ages .
#
# Spanish:	El Espíritu Santo nos asistirá en el servicio que prestemos a las familias .
# Translation:	The Holy Ghost will be in service in service to families .
# Target:		The Holy Ghost will attend us in our service to families .
#
# Spanish:	Los católicos creemos que nuestra vocación es ser la levadura de la sociedad .
# Translation:	We are believe that our favorite handcart income is to be society .
# Target:		We Catholics believe that our vocation is to be leaven in society .
#
# Spanish:	Él sanó a todos los que vinieron a Él ; ninguno fue rechazado .
# Translation:	He healed all that He came to pass the one of man .
# Target:		He healed all that came to Him . None were turned away .
#
# Spanish:	La caridad , en términos positivos , es paciente , benévola y feliz .
# Translation:	Charity , in charity , is patient , patient , and happy .
# Target:		Charity , in positive terms , is patient , kind , and content .
#
# Spanish:	Lo que de veras importa es que esta es la obra del Maestro ;
# Translation:	What is the very thing that is this the work of the Master ; the Master .
# Target:		What is really important is that this is the work of the Master .
#
# Spanish:	Están comprometidos a asegurarse de que verdaderamente se haga la voluntad del Señor .
# Translation:	They are willing to ensure that we truly do .
# Target:		They are committed to see that the Lord ’s will truly will be done .
#
# Spanish:	Él los conoce y ve el esfuerzo , diligencia y sacrificio de ustedes .
# Translation:	He knows and knows the effort , effort , and sacrifice of you .
# Target:		He knows you , and He sees your effort , diligence , and sacrifice .
#
# Spanish:	Podría significar dar vida emocional al desesperanzado o vida espiritual al que duda .
# Translation:	It could mean to give life or emotional life to the spiritual life .
# Target:		It could mean giving emotional life to the hopeless or spiritual life to the doubter .
#
# Spanish:	Aprendió el valor del trabajo arduo y obtuvo un testimonio del Salvador Jesucristo .
# Translation:	He learned the courage of hard work and received a testimony of the Savior Jesus Christ .
# Target:		He learned the value of hard work and cultivated a testimony of the Savior Jesus Christ .
#
# Spanish:	No sé si fue fácil para Daniel ser un creyente en tales circunstancias .
# Translation:	I do not know if Daniel was easy to be a sure thing in such circumstances .
# Target:		I do n’t know if it was easy for Daniel to be a believer in such an environment .
#
# Spanish:	Véase Enseñanzas de los Presidentes de la Iglesia : José Smith , pág. <unk> .
# Translation:	See Teachings of Presidents of the Church : Joseph Smith ( 1998 ) , 98 .
# Target:		In History of the Church , <unk> , footnote .
#
# Spanish:	Su respuesta rápida y alegre fue : “ Se llama Joy , o Alegría .
# Translation:	His reply and was a very answer , “ it is a great and joy .
# Target:		Her quick and cheerful answer was “ Her name is Joy .
#
# Spanish:	Esa práctica personal se basa en el estudio , la meditación y la oración .
# Translation:	That personal practice is based on study , study , and prayer .
# Target:		This personal practice is founded on study , meditation , and prayer .
#
# Spanish:	<unk> edificando templos por el mundo a medida que aumente nuestra cantidad de miembros .
# Translation:	We are to build temples the world as we increase our members of members .
# Target:		We will continue to build temples throughout the world as our membership grows .
#
# Spanish:	Eso lo llevó a cuestionar su llamamiento y a aquellos de quienes éste <unk> .
# Translation:	That took it to be the call of their calling and to those who are forced from the call .
# Target:		This caused him to question his call and those from whom it came .
#
# Spanish:	“ Ven , sígueme ” , fue la invitación del Señor al joven rico .
# Translation:	“ Come , Follow Me ” was the Lord ’s invitation to the young man .
# Target:		“ Follow me ” was the Lord ’s invitation to the rich young ruler .
#
# Spanish:	Para que el arrepentimiento surta efecto , debe ser específico , profundo y duradero .
# Translation:	For repentance , the effect , it must be a profound and lasting determination .
# Target:		For repentance to work , it must be specific , profound , and lasting .
#
# Spanish:	Naturalmente , el tener preguntas y dudas no es <unk> con el discipulado dedicado .
# Translation:	Of course , we have questions and questions are not limited to discipleship .
# Target:		Of course , having questions and experiencing doubts are not incongruent with dedicated discipleship .
#
# Spanish:	En ocasiones el mensaje será lo más importante que compartan en una visita particular .
# Translation:	At times the message will be more important than share a few who share the visit .
# Target:		Sometimes the message will be the most important thing you share on a particular visit .
#
# Spanish:	Obtuvo una licenciatura de la Universidad Brigham Young en estudios universitarios y estudios asiáticos .
# Translation:	He took a bachelor ’s degree from Brigham Young University in a bachelor ’s degree in economics .
# Target:		He received a bachelor ’s degree from Brigham Young University in University and Asian Studies .
#
# Spanish:	Miles de hombres y mujeres sinceros y devotos abrazaron la causa de la Restauración .
# Translation:	Thousands of men and women of the Restoration , and the truth of the Restoration .
# Target:		Tens of thousands of honest , devoted men and women embraced the cause of the Restoration .
#
# Spanish:	Me complace informar que este verano pasado se le restauraron a David sus bendiciones .
# Translation:	I am pleased to say this past summer past summer .
# Target:		I am happy to report that this past summer , David ’s blessings were restored to him .
#
# Spanish:	Primero , podemos hacerles notar a nuestros hijos cuando escuchan y sienten el Espíritu .
# Translation:	First , we can bring them to our children and feel the Spirit .
# Target:		First , we can bring to our children ’s attention when they are hearing and feeling the Spirit .
#
# Spanish:	Para el año <unk> , el desempleo en Utah había alcanzado un <unk> por ciento .
# Translation:	For the year the year , the Utah had been traveling by a half of trees .
# Target:		By <unk> unemployment in Utah had reached <unk> percent .
#
# Spanish:	Cada uno es un amado hijo o hija procreado como espíritu por padres celestiales ” .
# Translation:	Each is a beloved son or daughter of heavenly parents , ” by heavenly parents . ”
# Target:		Each is a beloved spirit son or daughter of heavenly parents . ”
#
# Spanish:	A medida que vivimos el Evangelio con diligencia , llegamos a fortalecernos en el Señor .
# Translation:	It invites Relief Society to attend the following Church members : Young Women General Authorities ; Area Seventies ; and Area Seventies , and stake mission president ; and stake Relief Society president ; and ward Young Women , Young Women , and stake presidents .
# Target:		The following members are invited to attend the broadcast : General Authorities ; Area Seventies ; stake , mission , temple , and district presidencies ; stake and district clerks ; stake and district executive secretaries ; high councilors ; stake and district Relief Society , Young Men , Young Women , Primary , and Sunday School presidencies ; bishoprics ; branch presidencies ; ward and branch clerks ; ward and branch executive secretaries ; high priests group leaders and assistants ; elders quorum presidencies ; ward and branch Relief Society , Young Men , Young Women , Primary , and Sunday School presidencies ; ward mission leaders .
#
# Spanish:	Se propone que sostengamos a los siguientes hermanos como nuevos Setentas de Área : Ian S. Ardern , Philip K. <unk> , René J. Cabrera , Renato <unk> , Paul D. M. Christensen , <unk> G. R. <unk> , Donald D. <unk> , George R. Donaldson , <unk> B. <unk> , Christian <unk> , Craig G. <unk> , <unk> L. <unk> , Jack N. Gerard , M. Keith <unk> , Brent J. <unk> , <unk> Chang Juan , George M. <unk> , <unk> O. <unk> , Alexander T. Mestre , <unk> V. <unk> , T. Jackson <unk> , S. Gifford Nielsen , <unk> F. <unk> , <unk> E. Olson , R. <unk> <unk> , Robert N. Packer , <unk> R. <unk> , <unk> A. <unk> Jr . , <unk> Pierre - <unk> , Michael J. <unk> , <unk> D. G. <unk> , <unk> K. <unk> , <unk> B. Soares , Carlos A. <unk> , <unk> de Souza <unk> , <unk> Tashiro , <unk> Villalobos , W. Christopher Waddell , Alan J. Webb , Gerardo J. <unk> , Kevin J. Worthen , Craig T. Wright y Jim L. Wright .
# Translation:	It is proposed that we sustain the following as new Area Seventies :
# Target:		All in favor , please signify .

# %% [markdown]
# <div id="disqus_thread"></div>
# <script>
#     /**
#      *  RECOMMENDED CONFIGURATION VARIABLES: EDIT AND UNCOMMENT THE SECTION BELOW TO INSERT DYNAMIC VALUES FROM YOUR PLATFORM OR CMS.
#      *  LEARN WHY DEFINING THESE VARIABLES IS IMPORTANT: https://disqus.com/admin/universalcode/#configuration-variables
#      */
#     /*
#     var disqus_config = function () {
#         this.page.url = PAGE_URL;  // Replace PAGE_URL with your page's canonical URL variable
#         this.page.identifier = PAGE_IDENTIFIER; // Replace PAGE_IDENTIFIER with your page's unique identifier variable
#     };
#     */
#     (function() {  // REQUIRED CONFIGURATION VARIABLE: EDIT THE SHORTNAME BELOW
#         var d = document, s = d.createElement('script');
#
#         s.src = 'https://EXAMPLE.disqus.com/embed.js';  // IMPORTANT: Replace EXAMPLE with your forum shortname!
#
#         s.setAttribute('data-timestamp', +new Date());
#         (d.head || d.body).appendChild(s);
#     })();
# </script>
# <noscript>Please enable JavaScript to view the <a href="https://disqus.com/?ref_noscript" rel="nofollow">comments powered by Disqus.</a></noscript>
