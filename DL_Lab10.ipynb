# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab10.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# #Lab 10: Transfer Learning/Fine-Tuning

# %% [markdown]
# ## Description

# %% [markdown]
# ### Objective
#
# - Gain experience fine-tuning pre-trained models to domain-specific applications.
#
# ### Deliverable
#
# For this lab you will submit an ipython notebook via learning suite. The bulk of the work is in modifying fine-tuning a pre-trained ResNet. Fine-tuning the GPT-2 language model is pretty easy. The provided code works as is; you will just have to swap in your own text dataset.
#
# ### Grading
#
# - 35% Create a dataset class for your own dataset
# - 35% Create a network class that wraps a pretrained ResNet
# - 20% Implement unfreezing in the network class
# - 10% Fine-tune GPT-2 on your own dataset
#
# ### Tips
# - Your life will be better if you download a dataset that already has the data in the expected format for ImageFolder (make sure to read the documentation!). The datasets recommended below are in the correct format.
# - Get the CNN working on the provided dataset (bird species classification) before swapping in your own.
# - For reference on freezing/unfreezing network weights, see [this github gist](https://gist.github.com/jcjohnson/6e41e8512c17eae5da50aebef3378a4c)
# - For training GPT-2, first try the medium-size (355M parameter) model. If your Colab instance doesn't have enough GPU space, you may need to switch to the small-size (124M parameter) model, but the results will be less impressive.

# %%
from torchvision.models import resnet152
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, Dataset
import torch
from torch import optim, nn
import zipfile
from google.colab import files
import os
import sys
from PIL import Image, ImageOps
from tqdm import tqdm
import numpy as np
from matplotlib import pyplot as plt
import gc

# %% [markdown]
# ## 1 Fine-tune a ResNet for image classification

# %% [markdown]
# ### 1.1 Find a dataset to fine-tune on, and make a Dataset class (1 hr.)

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Inherit from torch.utils.data.Dataset
# - Use a [torchvision.datasets.ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#torchvision.datasets.ImageFolder)
# - Don't spend too long finding another dataset. Some suggestions that you are free to use:
#  - https://www.kaggle.com/akash2907/bird-species-classification
#  - https://www.kaggle.com/jessicali9530/stanford-dogs-dataset
#  - https://www.kaggle.com/puneet6060/intel-image-classification

# %% [markdown]
# #### Help for downloading kaggle datasets
# Downloading Kaggle datasets requires authentication, so you can't just download from a url. Here are some step-by-step instructions of how to get Kaggle datasets in Colab

# %% [markdown]
# 1. Create an API key in Kaggle
#     - Click on profile photo
#     - Go to 'My Account'
#     - Scroll down to the API access section and click "Create New API Token"
#     - `kaggle.json` is now downloaded to your computer
#
# 2. Upload the API key and install the Kaggle API client by running the next cell (run it again if it throws an error the first time). Also, `files.upload()` may not work in Firefox. One solution is to expand the Files banner (indicated by the '>' tab on the left side of the page) and use that to upload the key.

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import drive

drive.mount('/content/drive')

# !pip install kaggle

# !mkdir -p ~/.kaggle
# !cp '/content/drive/My Drive/Colab Notebooks/kaggle.json' ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !mkdir -p /content/data
# Out:
# Mounted at /content/drive
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.9)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (0.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)

# %% [markdown]
# 3. Copy the desired dataset locally

# %%
# Example download command for dataset found here: https://www.kaggle.com/akash2907/bird-species-classification
# !kaggle datasets download -d akash2907/bird-species-classification
# !kaggle datasets download -d ucffool/dice-d4-d6-d8-d10-d12-d20-images
# !kaggle datasets download -d puneet6060/intel-image-classification
# Out:
# Downloading dice-d4-d6-d8-d10-d12-d20-images.zip to /content
#  98% 661M/676M [00:03<00:00, 282MB/s]
# 100% 676M/676M [00:03<00:00, 222MB/s]

# %% [markdown]
# #### Make the Dataset class
# See the implementation below for reference, and make your own.

# %%
class BirdDataset(Dataset):
    def __init__(self, zip_file='bird-species-classification.zip', size=256, train=True, upload=False):
        super(BirdDataset, self).__init__()
        
        self.train = train
        extract_dir = os.path.splitext(zip_file)[0]
        if not os.path.exists(extract_dir):
            os.makedirs(extract_dir)
            self.extract_zip(zip_file, extract_dir)
            # Resize the images - originally they are high resolution. We could do this
            # in the DataLoader, but it will read the full-resolution files from disk
            # every time before resizing them, making training slow
            self.resize(extract_dir, size=size)

        postfix = 'train' if train else 'test'
            
        if train:
            # The bird-species dataset mistakenly has a train_data folder inside of train_data
            self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'train_data', 'train_data'), transform=transforms.Compose([transforms.ToTensor()]))
        else:
            self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'test_data', 'test_data'), transform=transforms.Compose([transforms.ToTensor()]))

    def extract_zip(self, zip_file, extract_dir):
        print("Extracting", zip_file)
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)

    def resize(self, path, size=256):
        """Resizes all images in place"""
        print("Resizing images")
        dirs = os.walk(path)
        for root, dirs, files in os.walk(path):
            for item in files:
                name = os.path.join(root, item)
                if os.path.isfile(name):
                    im = Image.open(name)
                    im = ImageOps.fit(im, (size, size))
                    im.save(name[:-3] + 'bmp', 'BMP')
                    os.remove(name)

    def __getitem__(self, i):
        return self.dataset_folder[i]

    def __len__(self):
        return len(self.dataset_folder)

# bird_data = BirdDataset()

# %%
#########################
# Implement your own Dataset
#########################
class DiceDataset(nn.Module):
  def __init__(self, zip_file='dice-d4-d6-d8-d10-d12-d20-images.zip', size=256, train=True, upload=False):
    super(DiceDataset, self).__init__()

    self.train = train
    extract_dir = os.path.splitext(zip_file)[0]
    if not os.path.exists(extract_dir):
      os.makedirs(extract_dir)
      self.extract_zip(zip_file, extract_dir)
      self.resize(extract_dir, size=size)
    
    postfix = 'train' if train else 'test'

    if train:
      self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'dice', 'train'), transform=transforms.Compose([transforms.ToTensor()]))
    else:
      self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'dice', 'valid'), transform=transforms.Compose([transforms.ToTensor()]))


  def extract_zip(self, zip_file, extract_dir):
    print("Extracting", zip_file)
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
      zip_ref.extractall(extract_dir)


  def resize(self, path, size=256, keep_portion=10):
    """Resizes all images in place"""
    print("Resizing images in ", path)
    dirs = os.walk(path)
    for root, dirs, files in os.walk(path):
      for item in files:
        name = os.path.join(root, item)
        # print(os.path.splitext(name)[-1].lower())
        if os.path.isfile(name) and os.path.splitext(name)[-1].lower() == '.jpg':
          # print('\r', 'resizing: ', name, end='', flush=True)
          remainder = 0
          try:
            remainder = int(os.path.splitext(item)[0][-3:])
            print('\r', remainder, end=' ')
          except:
            print('\r', 'not a number ', remainder, end=' ')
          
          if remainder % keep_portion == 0:
            print('---> keeping ', item, end='')
            im = Image.open(name)
            im = ImageOps.fit(im, (size, size))
            im.save(name[:-3] + 'bmp', 'BMP')
            im.close()
          os.remove(name)

  def __getitem__(self, i):
    return self.dataset_folder[i]

  def __len__(self):
    return len(self.dataset_folder)


# dice_data = DiceDataset()

# %%
#########################
# Implement your own Dataset
#########################
class IntelDataset(nn.Module):
  def __init__(self, zip_file='intel-image-classification.zip', size=256, train=True, upload=False):
    super(IntelDataset, self).__init__()

    self.train = train
    extract_dir = os.path.splitext(zip_file)[0]
    if not os.path.exists(extract_dir):
      os.makedirs(extract_dir)
      self.extract_zip(zip_file, extract_dir)
      self.resize(extract_dir, size=size)
    
    postfix = 'train' if train else 'test'

    if train:
      self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'seg_train', 'seg_train'), transform=transforms.Compose([transforms.ToTensor()]))
    else:
      self.dataset_folder = datasets.ImageFolder(os.path.join(extract_dir, 'seg_test', 'set_test'), transform=transforms.Compose([transforms.ToTensor()]))


  def extract_zip(self, zip_file, extract_dir):
    print("Extracting", zip_file)
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
      zip_ref.extractall(extract_dir)


  def resize(self, path, size=256, keep_portion=8):
    """Resizes all images in place"""
    print("Resizing images in ", path)
    dirs = os.walk(path)
    for root, dirs, files in os.walk(path):
      for item in files:
        name = os.path.join(root, item)
        # print(os.path.splitext(name)[-1].lower())
        if os.path.isfile(name) and os.path.splitext(name)[-1].lower() == '.jpg':
          # print('\r', 'resizing: ', name, end='', flush=True)
          remainder = 0
          try:
            remainder = int(os.path.splitext(item)[0][-3:])
            print('\r', remainder, end=' ')
          except:
            print('\r', 'not a number ', remainder, end=' ')
          
          if remainder % keep_portion == 0:
            print('---> keeping ', item, end='')
            im = Image.open(name)
            im = ImageOps.fit(im, (size, size))
            im.save(name[:-3] + 'bmp', 'BMP')
          os.remove(name)

  def __getitem__(self, i):
    return self.dataset_folder[i]

  def __len__(self):
    return len(self.dataset_folder)


# intel_data = IntelDataset()

# %% [markdown]
# ### 1.2 Wrap a pretrained ResNet in an `nn.Module` (30 min)

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Make a model class that inherits from `nn.Module`
# - Wrap a pretrained ResNet and swap out the last layer of that network with a layer that maps to the number of classes in your new dataset

# %% [markdown]
# #### Make your model class

# %%
class ResNetBirds(nn.Module):
    def __init__(self, num_classes, start_frozen=False):
        super(ResNetBirds, self).__init__()

        # Part 1.2
        # Load the model - make sure it is pre-trained
        self.model = resnet152(pretrained=True)

        self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)
        
        for param in self.model.parameters():
          param.requires_grad = False
        self.unfrozen = 1

        # Part 1.4
        if not start_frozen:
          for param in self.model.fc.parameters():
            param.requires_grad = True
          self.unfrozen = 0
        
    def unfreeze(self, n_layers):
        # Part 1.4
        # Turn on gradients for the last n_layers
        print(self.unfrozen, n_layers)
        parameters = list(self.model.parameters())
        
        for param in (parameters[-n_layers:] if self.unfrozen == 0 else parameters[-n_layers:-self.unfrozen]):
          param.requires_grad = True
        self.unfrozen = n_layers     

    def forward(self, x):
        # Part 1.2
        # Pass x through the resnet
        return self.model(x)

# %% [markdown]
# ### 1.3 Read through and run this training loop

# %%
def accuracy(y_hat, y_truth):
    """Gets average accuracy of a vector of predictions"""
    
    preds = torch.argmax(y_hat, dim=1)
    acc = torch.mean((preds == y_truth).float())
    return acc

def evaluate(model, objective, val_loader, device):
    """Gets average accuracy and loss for the validation set"""

    val_losses = []
    val_accs = []
    # model.eval() so that batchnorm and dropout work in eval mode
    model.eval()
    # torch.no_grad() to turn off computation graph creation. This allows for temporal
    # and spatial complexity improvements, which allows for larger validation batch 
    # sizes so it’s recommended
    with torch.no_grad():
        for x, y_truth in val_loader:

            x, y_truth = x.to(device), y_truth.to(device)
            y_hat = model(x)
            val_loss = objective(y_hat, y_truth)
            val_acc = accuracy(y_hat, y_truth)

            val_losses.append(val_loss.item())
            val_accs.append(val_acc)

    model.train()
    gc.collect()
    return torch.mean(torch.Tensor(val_losses)), torch.mean(torch.Tensor(val_accs))

# %%
def train(start_frozen=False, model_unfreeze=0, d_set='dice'):
    """Fine-tunes a CNN
    Args:
        start_frozen (bool): whether to start with the network weights frozen.
        model_unfreeze (int): the maximum number of network layers to unfreeze
    """
    epochs = 20
    # Start with a very low learning rate
    lr = .00005
    val_every = 3
    class_dict = {'bird': 16, 'dice': 6, 'intel': 6}
    num_classes = class_dict[d_set]
    size_dict = {'bird': 32, 'dice': 32, 'intel': 32}
    batch_size = size_dict[d_set]
    device = torch.device('cuda:0')

    # Data
    def setup(upload, train, d_set):
      if d_set is 'bird':
        return BirdDataset(upload=upload, train=train)
      elif d_set is 'dice':
        return DiceDataset(upload=upload, train=train)
      elif d_set is 'intel':
        return IntelDataset(upload=upload, train=train)
      else:
        return DiceDataset(upload=upload, train=train)

    train_dataset = setup(True, True, d_set)
    val_dataset = setup(True, False, d_set)
    train_loader = DataLoader(train_dataset,
                              shuffle=True,
                              num_workers=8,
                              batch_size=batch_size)
    val_loader = DataLoader(val_dataset,
                              shuffle=True,
                              num_workers=8,
                              batch_size=batch_size)
    
    # Model
    model = ResNetBirds(num_classes, start_frozen=start_frozen).to(device)
    
    # Objective
    objective = nn.CrossEntropyLoss()
    # Optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-1)

    # Progress bar
    pbar = tqdm(total=len(train_loader) * epochs)

    train_losses = []
    train_accs = []
    val_losses = []
    val_accs = []
    
    cnt = 0
    for epoch in range(epochs):
        gc.collect()

        # Implement model unfreezing
        if epoch < model_unfreeze:
            # Part 1.4
            # Unfreeze the last layers, one more each epoch
            model.unfreeze(epoch)
        
        for x, y_truth in train_loader:
            gc.collect()
        
            x, y_truth = x.to(device), y_truth.to(device)

            optimizer.zero_grad()

            y_hat = model(x)
            train_loss = objective(y_hat, y_truth)
            train_acc = accuracy(y_hat, y_truth)

            train_loss.backward()
            optimizer.step()

            train_accs.append(train_acc)
            train_losses.append(train_loss.item())

            if cnt % val_every == 0:
                val_loss, val_acc = evaluate(model, objective, val_loader, device)
                val_losses.append(val_loss)
                val_accs.append(val_acc)

            pbar.set_description('train loss:{:.4f}, train accuracy:{:.4f}.'.format(train_loss.item(), train_acc))
            pbar.update(1)
            cnt += 1

    pbar.close()
    plt.subplot(121)
    plt.plot(np.arange(len(train_accs)), train_accs, label='Train Accuracy')
    plt.plot(np.arange(len(train_accs), step=val_every), val_accs, label='Val Accuracy')
    plt.legend()
    plt.subplot(122)
    plt.plot(np.arange(len(train_losses)), train_losses, label='Train Loss')
    plt.plot(np.arange(len(train_losses), step=val_every), val_losses, label='Val Loss')
    plt.legend()
    plt.show()

# %%
gc.collect()
# Out:
# 0

# %%
gc.collect()
train(start_frozen=False, model_unfreeze=0, d_set='bird')
# Out:
# Extracting bird-species-classification.zip
# Resizing images
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss:3.0146, train accuracy:0.0000.:   0%|          | 0/100 [00:03<?, ?it/s]
# train loss:3.0146, train accuracy:0.0000.:   1%|          | 1/100 [00:03<05:38,  3.42s/it]
# train loss:2.8421, train accuracy:0.0625.:   1%|          | 1/100 [00:03<05:38,  3.42s/it]
# train loss:2.8421, train accuracy:0.0625.:   2%|▏         | 2/100 [00:03<04:05,  2.51s/it]
# train loss:2.8714, train accuracy:0.0938.:   2%|▏         | 2/100 [00:04<04:05,  2.51s/it]
# train loss:2.8714, train accuracy:0.0938.:   3%|▎         | 3/100 [00:04<03:00,  1.87s/it]
# train loss:2.9537, train accuracy:0.0625.:   3%|▎         | 3/100 [00:06<03:00,  1.87s/it]
# train loss:2.9537, train accuracy:0.0625.:   4%|▍         | 4/100 [00:06<03:18,  2.07s/it]
# train loss:2.7777, train accuracy:0.0909.:   4%|▍         | 4/100 [00:06<03:18,  2.07s/it]
# train loss:2.7777, train accuracy:0.0909.:   5%|▌         | 5/100 [00:07<02:25,  1.54s/it]
# train loss:2.7973, train accuracy:0.1875.:   5%|▌         | 5/100 [00:08<02:25,  1.54s/it]
# train loss:2.7973, train accuracy:0.1875.:   6%|▌         | 6/100 [00:08<02:14,  1.43s/it]
# train loss:2.8954, train accuracy:0.0312.:   6%|▌         | 6/100 [00:10<02:14,  1.43s/it]
# train loss:2.8954, train accuracy:0.0312.:   7%|▋         | 7/100 [00:10<02:47,  1.80s/it]
# train loss:2.8324, train accuracy:0.0625.:   7%|▋         | 7/100 [00:11<02:47,  1.80s/it]
# train loss:2.8324, train accuracy:0.0625.:   8%|▊         | 8/100 [00:11<02:06,  1.38s/it]
# train loss:0.6383, train accuracy:0.8750.:  94%|█████████▎| 524/560 [18:22<01:10,  1.95s/it]
# train loss:0.6383, train accuracy:0.8750.:  94%|█████████▍| 525/560 [18:22<00:55,  1.57s/it]
# train loss:0.6451, train accuracy:0.8750.:  94%|█████████▍| 525/560 [18:27<00:55,  1.57s/it]
# train loss:0.6451, train accuracy:0.8750.:  94%|█████████▍| 526/560 [18:27<01:25,  2.51s/it]
# train loss:0.6441, train accuracy:0.8594.:  94%|█████████▍| 526/560 [18:27<01:25,  2.51s/it]
# train loss:0.6441, train accuracy:0.8594.:  94%|█████████▍| 527/560 [18:27<01:04,  1.96s/it]
# train loss:0.6865, train accuracy:0.9375.:  94%|█████████▍| 527/560 [18:28<01:04,  1.96s/it]
# train loss:0.6865, train accuracy:0.9375.:  94%|█████████▍| 528/560 [18:28<00:50,  1.59s/it]
# train loss:0.6160, train accuracy:0.9219.:  94%|█████████▍| 528/560 [18:33<00:50,  1.59s/it]
# train loss:0.6160, train accuracy:0.9219.:  94%|█████████▍| 529/560 [18:33<01:18,  2.53s/it]
# train loss:0.6557, train accuracy:0.9219.:  94%|█████████▍| 529/560 [18:33<01:18,  2.53s/it]
# train loss:0.6557, train accuracy:0.9219.:  95%|█████████▍| 530/560 [18:33<00:59,  1.98s/it]
# train loss:0.6274, train accuracy:0.9219.:  95%|█████████▍| 530/560 [18:34<00:59,  1.98s/it]
# train loss:0.6274, train accuracy:0.9219.:  95%|█████████▍| 531/560 [18:34<00:46,  1.60s/it]
# train loss:0.5641, train accuracy:1.0000.:  95%|█████████▍| 531/560 [18:39<00:46,  1.60s/it]
# train loss:0.5641, train accuracy:1.0000.:  95%|█████████▌| 532/560 [18:39<01:07,  2.43s/it]
# train loss:0.5551, train accuracy:0.9531.:  95%|█████████▌| 532/560 [18:41<01:07,  2.43s/it]
# train loss:0.5551, train accuracy:0.9531.:  95%|█████████▌| 533/560 [18:41<01:07,  2.49s/it]
# train loss:0.5624, train accuracy:0.9688.:  95%|█████████▌| 533/560 [18:42<01:07,  2.49s/it]
# train loss:0.5624, train accuracy:0.9688.:  95%|█████████▌| 534/560 [18:42<00:50,  1.96s/it]
# train loss:0.6364, train accuracy:0.8750.:  95%|█████████▌| 534/560 [18:47<00:50,  1.96s/it]
# train loss:0.6364, train accuracy:0.8750.:  96%|█████████▌| 535/560 [18:47<01:09,  2.78s/it]
# train loss:0.6118, train accuracy:0.8750.:  96%|█████████▌| 535/560 [18:47<01:09,  2.78s/it]
# train loss:0.6118, train accuracy:0.8750.:  96%|█████████▌| 536/560 [18:47<00:51,  2.16s/it]
# train loss:0.6565, train accuracy:0.8594.:  96%|█████████▌| 536/560 [18:48<00:51,  2.16s/it]
# train loss:0.6565, train accuracy:0.8594.:  96%|█████████▌| 537/560 [18:48<00:39,  1.72s/it]
# train loss:0.6791, train accuracy:0.9531.:  96%|█████████▌| 537/560 [18:53<00:39,  1.72s/it]
# train loss:0.6791, train accuracy:0.9531.:  96%|█████████▌| 538/560 [18:53<00:57,  2.63s/it]
# train loss:0.5649, train accuracy:0.9531.:  99%|█████████▊| 552/560 [19:23<00:12,  1.59s/it]
# train loss:0.5649, train accuracy:0.9531.:  99%|█████████▉| 553/560 [19:23<00:17,  2.51s/it]
# train loss:0.6290, train accuracy:0.9375.:  99%|█████████▉| 553/560 [19:24<00:17,  2.51s/it]
# train loss:0.6290, train accuracy:0.9375.:  99%|█████████▉| 554/560 [19:24<00:11,  1.96s/it]
# train loss:0.5761, train accuracy:0.9688.:  99%|█████████▉| 554/560 [19:25<00:11,  1.96s/it]
# train loss:0.5761, train accuracy:0.9688.:  99%|█████████▉| 555/560 [19:25<00:07,  1.59s/it]
# train loss:0.5932, train accuracy:0.9062.:  99%|█████████▉| 555/560 [19:29<00:07,  1.59s/it]
# train loss:0.5932, train accuracy:0.9062.:  99%|█████████▉| 556/560 [19:29<00:10,  2.51s/it]
# train loss:0.5408, train accuracy:0.9688.:  99%|█████████▉| 556/560 [19:30<00:10,  2.51s/it]
# train loss:0.5408, train accuracy:0.9688.:  99%|█████████▉| 557/560 [19:30<00:05,  1.96s/it]
# train loss:0.6546, train accuracy:0.9219.:  99%|█████████▉| 557/560 [19:31<00:05,  1.96s/it]
# train loss:0.6546, train accuracy:0.9219.: 100%|█████████▉| 558/560 [19:31<00:03,  1.59s/it]
# train loss:0.5459, train accuracy:0.9375.: 100%|█████████▉| 558/560 [19:35<00:03,  1.59s/it]
# train loss:0.5459, train accuracy:0.9375.: 100%|█████████▉| 559/560 [19:35<00:02,  2.51s/it]
# train loss:0.8267, train accuracy:0.8800.: 100%|█████████▉| 559/560 [19:36<00:02,  2.51s/it]
# train loss:0.8267, train accuracy:0.8800.: 100%|██████████| 560/560 [19:36<00:00,  2.10s/it]

# %% [markdown]
# ### 1.4 Implement Unfreezing (1 hr)

# %% [markdown]
# #### Description

# %% [markdown]
# Unfreezing is a technique that can be helpful when fine tuning a CNN for a more difficult task with a large amount of data.
#
# The idea is that if we allow the network to tweak the earliest layers immediately, before the last FCL has been trained at all, the earliest layers will forget all of the useful features that they learned in order  to provide features that are helpful for the (untrained) FCL.
#
# So, rather than training all of the model weights at once, we learn the last fully connected layer, then train that layer together with the second-to-last layer, gradually adding layers until we reach the first layer.

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Modify your model class by setting the `requires_grad` attribute of the ResNet to `False`. (but keep `requires_grad = True` for the last layer).
# - Add a member function to you model class that allows the user to unfreeze weights in the training loop. See [this github gist](https://gist.github.com/jcjohnson/6e41e8512c17eae5da50aebef3378a4c) for reference.
# - Modify your training loop to add logic that calls the `unfreeze` function of the model class (unfreeze one layer every epoch).
# - Call your train function to fine-tune the ResNet on your dataset.

# %% [markdown]
# #### Call your train function

# %%
gc.collect()
train(start_frozen=False, model_unfreeze=20, d_set='bird')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#
# train loss:2.8105, train accuracy:0.0625.:   0%|          | 0/100 [00:03<?, ?it/s]
#
# train loss:2.8105, train accuracy:0.0625.:   1%|          | 1/100 [00:03<06:30,  3.95s/it]
#
# train loss:2.7515, train accuracy:0.0625.:   1%|          | 1/100 [00:05<06:30,  3.95s/it]
#
# train loss:2.7515, train accuracy:0.0625.:   2%|▏         | 2/100 [00:05<05:02,  3.08s/it]
#
# train loss:2.6655, train accuracy:0.0938.:   2%|▏         | 2/100 [00:06<05:02,  3.08s/it]
#
# train loss:2.6655, train accuracy:0.0938.:   3%|▎         | 3/100 [00:06<04:00,  2.48s/it]
#
# train loss:2.6497, train accuracy:0.0625.:   3%|▎         | 3/100 [00:09<04:00,  2.48s/it]
#
# train loss:2.6497, train accuracy:0.0625.:   4%|▍         | 4/100 [00:09<04:21,  2.72s/it]
#
# train loss:2.5311, train accuracy:0.3182.:   4%|▍         | 4/100 [00:10<04:21,  2.72s/it]
#
# train loss:2.5311, train accuracy:0.3182.:   5%|▌         | 5/100 [00:10<03:22,  2.13s/it]
#
# train loss:2.1881, train accuracy:0.6875.:   5%|▌         | 5/100 [00:12<03:22,  2.13s/it]
#
# train loss:2.1881, train accuracy:0.6875.:   6%|▌         | 6/100 [00:12<03:14,  2.07s/it]
#
# train loss:2.2495, train accuracy:0.5000.:   6%|▌         | 6/100 [00:15<03:14,  2.07s/it]
#
# train loss:2.2495, train accuracy:0.5000.:   7%|▋         | 7/100 [00:15<03:49,  2.46s/it]
#
# train loss:2.1067, train accuracy:0.6562.:   7%|▋         | 7/100 [00:16<03:49,  2.46s/it]
#
# train loss:2.1067, train accuracy:0.6562.:   8%|▊         | 8/100 [00:16<03:08,  2.05s/it]
#
# train loss:2.0388, train accuracy:0.8438.:   8%|▊         | 8/100 [00:17<03:08,  2.05s/it]
#
# train loss:2.0388, train accuracy:0.8438.:   9%|▉         | 9/100 [00:17<02:40,  1.76s/it]
#
# train loss:1.9525, train accuracy:0.8636.:   9%|▉         | 9/100 [00:20<02:40,  1.76s/it]
#
# train loss:1.9525, train accuracy:0.8636.:  10%|█         | 10/100 [00:20<03:16,  2.18s/it]
#
# train loss:1.8305, train accuracy:0.8438.:  10%|█         | 10/100 [00:22<03:16,  2.18s/it]
#
# train loss:1.8305, train accuracy:0.8438.:  11%|█         | 11/100 [00:22<03:06,  2.10s/it]
#
# train loss:1.7090, train accuracy:0.8438.:  11%|█         | 11/100 [00:23<03:06,  2.10s/it]
#
# train loss:1.7090, train accuracy:0.8438.:  12%|█▏        | 12/100 [00:23<02:38,  1.81s/it]
#
# train loss:1.6076, train accuracy:0.9375.:  12%|█▏        | 12/100 [00:27<02:38,  1.81s/it]
#
# train loss:1.6076, train accuracy:0.9375.:  13%|█▎        | 13/100 [00:27<03:22,  2.33s/it]
#
# train loss:1.6850, train accuracy:0.7812.:  13%|█▎        | 13/100 [00:28<03:22,  2.33s/it]
#
# train loss:1.6850, train accuracy:0.7812.:  14%|█▍        | 14/100 [00:28<02:48,  1.96s/it]
#
# train loss:1.4742, train accuracy:0.9545.:  14%|█▍        | 14/100 [00:29<02:48,  1.96s/it]
#
# train loss:1.4742, train accuracy:0.9545.:  15%|█▌        | 15/100 [00:29<02:16,  1.61s/it]
#
# train loss:1.3400, train accuracy:1.0000.:  15%|█▌        | 15/100 [00:33<02:16,  1.61s/it]
#
# train loss:1.3400, train accuracy:1.0000.:  16%|█▌        | 16/100 [00:33<03:23,  2.42s/it]
#
# train loss:1.4089, train accuracy:0.8125.:  16%|█▌        | 16/100 [00:34<03:23,  2.42s/it]
#
# train loss:1.4089, train accuracy:0.8125.:  17%|█▋        | 17/100 [00:34<02:48,  2.03s/it]
#
# train loss:1.3393, train accuracy:0.9375.:  17%|█▋        | 17/100 [00:35<02:48,  2.03s/it]
#
# train loss:1.3393, train accuracy:0.9375.:  18%|█▊        | 18/100 [00:35<02:24,  1.76s/it]
#
# train loss:1.2064, train accuracy:0.9062.:  18%|█▊        | 18/100 [00:39<02:24,  1.76s/it]
#
# train loss:1.2064, train accuracy:0.9062.:  19%|█▉        | 19/100 [00:39<03:02,  2.25s/it]
#
# train loss:1.2757, train accuracy:0.7727.:  19%|█▉        | 19/100 [00:39<03:02,  2.25s/it]
#
# train loss:1.2757, train accuracy:0.7727.:  20%|██        | 20/100 [00:39<02:25,  1.81s/it]
#
# train loss:1.0365, train accuracy:0.9375.:  20%|██        | 20/100 [00:41<02:25,  1.81s/it]
#
# train loss:1.0365, train accuracy:0.9375.:  21%|██        | 21/100 [00:41<02:25,  1.84s/it]
#
# train loss:1.1000, train accuracy:0.9375.:  21%|██        | 21/100 [00:45<02:25,  1.84s/it]
#
# train loss:1.1000, train accuracy:0.9375.:  22%|██▏       | 22/100 [00:45<03:00,  2.31s/it]
#
# train loss:0.9472, train accuracy:0.9375.:  22%|██▏       | 22/100 [00:46<03:00,  2.31s/it]
#
# train loss:0.9472, train accuracy:0.9375.:  23%|██▎       | 23/100 [00:46<02:29,  1.94s/it]
#
# train loss:1.0057, train accuracy:0.9062.:  23%|██▎       | 23/100 [00:47<02:29,  1.94s/it]
#
# train loss:1.0057, train accuracy:0.9062.:  24%|██▍       | 24/100 [00:47<02:07,  1.68s/it]
#
# train loss:1.1457, train accuracy:0.8636.:  24%|██▍       | 24/100 [00:50<02:07,  1.68s/it]
#
# train loss:1.1457, train accuracy:0.8636.:  25%|██▌       | 25/100 [00:50<02:37,  2.11s/it]
#
# train loss:0.8570, train accuracy:0.9688.:  25%|██▌       | 25/100 [00:52<02:37,  2.11s/it]
#
# train loss:0.8570, train accuracy:0.9688.:  26%|██▌       | 26/100 [00:52<02:30,  2.03s/it]
#
# train loss:0.8639, train accuracy:0.9688.:  26%|██▌       | 26/100 [00:53<02:30,  2.03s/it]
#
# train loss:0.8639, train accuracy:0.9688.:  27%|██▋       | 27/100 [00:53<02:07,  1.75s/it]
#
# train loss:0.8201, train accuracy:0.9688.:  27%|██▋       | 27/100 [00:56<02:07,  1.75s/it]
#
# train loss:0.8201, train accuracy:0.9688.:  28%|██▊       | 28/100 [00:56<02:40,  2.23s/it]
#
# train loss:0.8522, train accuracy:0.9688.:  28%|██▊       | 28/100 [00:57<02:40,  2.23s/it]
#
# train loss:0.8522, train accuracy:0.9688.:  29%|██▉       | 29/100 [00:57<02:13,  1.88s/it]
#
# train loss:0.8071, train accuracy:0.9545.:  29%|██▉       | 29/100 [00:58<02:13,  1.88s/it]
#
# train loss:0.8071, train accuracy:0.9545.:  30%|███       | 30/100 [00:58<01:48,  1.55s/it]
#
# train loss:0.6023, train accuracy:1.0000.:  30%|███       | 30/100 [01:02<01:48,  1.55s/it]
#
# train loss:0.6023, train accuracy:1.0000.:  31%|███       | 31/100 [01:02<02:40,  2.33s/it]
#
# train loss:0.5292, train accuracy:0.9688.:  31%|███       | 31/100 [01:03<02:40,  2.33s/it]
#
# train loss:0.5292, train accuracy:0.9688.:  32%|███▏      | 32/100 [01:03<02:12,  1.95s/it]
#
# train loss:0.6829, train accuracy:0.9688.:  32%|███▏      | 32/100 [01:04<02:12,  1.95s/it]
#
# train loss:0.6829, train accuracy:0.9688.:  33%|███▎      | 33/100 [01:04<01:52,  1.68s/it]
#
# train loss:0.5707, train accuracy:1.0000.:  33%|███▎      | 33/100 [01:08<01:52,  1.68s/it]
#
# train loss:0.5707, train accuracy:1.0000.:  34%|███▍      | 34/100 [01:08<02:24,  2.19s/it]
#
# train loss:0.7985, train accuracy:0.9545.:  34%|███▍      | 34/100 [01:09<02:24,  2.19s/it]
#
# train loss:0.7985, train accuracy:0.9545.:  35%|███▌      | 35/100 [01:09<01:54,  1.76s/it]
#
# train loss:0.6025, train accuracy:1.0000.:  35%|███▌      | 35/100 [01:10<01:54,  1.76s/it]
#
# train loss:0.6025, train accuracy:1.0000.:  36%|███▌      | 36/100 [01:10<01:54,  1.80s/it]
#
# train loss:0.5178, train accuracy:1.0000.:  36%|███▌      | 36/100 [01:14<01:54,  1.80s/it]
#
# train loss:0.5178, train accuracy:1.0000.:  37%|███▋      | 37/100 [01:14<02:22,  2.27s/it]
#
# train loss:0.3957, train accuracy:0.9688.:  37%|███▋      | 37/100 [01:15<02:22,  2.27s/it]
#
# train loss:0.3957, train accuracy:0.9688.:  38%|███▊      | 38/100 [01:15<01:58,  1.91s/it]
#
# train loss:0.4177, train accuracy:1.0000.:  38%|███▊      | 38/100 [01:16<01:58,  1.91s/it]
#
# train loss:0.4177, train accuracy:1.0000.:  39%|███▉      | 39/100 [01:16<01:41,  1.66s/it]
#
# train loss:0.5901, train accuracy:1.0000.:  39%|███▉      | 39/100 [01:19<01:41,  1.66s/it]
#
# train loss:0.5901, train accuracy:1.0000.:  40%|████      | 40/100 [01:19<02:04,  2.07s/it]
#
# train loss:0.4509, train accuracy:1.0000.:  40%|████      | 40/100 [01:21<02:04,  2.07s/it]
#
# train loss:0.4509, train accuracy:1.0000.:  41%|████      | 41/100 [01:21<01:59,  2.02s/it]
#
# train loss:0.3164, train accuracy:1.0000.:  41%|████      | 41/100 [01:22<01:59,  2.02s/it]
#
# train loss:0.3164, train accuracy:1.0000.:  42%|████▏     | 42/100 [01:22<01:40,  1.74s/it]
#
# train loss:0.4254, train accuracy:1.0000.:  42%|████▏     | 42/100 [01:25<01:40,  1.74s/it]
#
# train loss:0.4254, train accuracy:1.0000.:  43%|████▎     | 43/100 [01:25<02:07,  2.24s/it]
#
# train loss:0.1263, train accuracy:1.0000.:  84%|████████▍ | 84/100 [02:47<00:26,  1.66s/it]
#
# train loss:0.1263, train accuracy:1.0000.:  85%|████████▌ | 85/100 [02:47<00:31,  2.08s/it]
#
# train loss:0.0987, train accuracy:1.0000.:  85%|████████▌ | 85/100 [02:49<00:31,  2.08s/it]
#
# train loss:0.0987, train accuracy:1.0000.:  86%|████████▌ | 86/100 [02:49<00:28,  2.02s/it]
#
# train loss:0.0909, train accuracy:1.0000.:  86%|████████▌ | 86/100 [02:50<00:28,  2.02s/it]
#
# train loss:0.0909, train accuracy:1.0000.:  87%|████████▋ | 87/100 [02:50<00:22,  1.75s/it]
#
# train loss:0.1533, train accuracy:1.0000.:  87%|████████▋ | 87/100 [02:53<00:22,  1.75s/it]
#
# train loss:0.1533, train accuracy:1.0000.:  88%|████████▊ | 88/100 [02:53<00:26,  2.24s/it]
#
# train loss:0.1227, train accuracy:1.0000.:  88%|████████▊ | 88/100 [02:54<00:26,  2.24s/it]
#
# train loss:0.1227, train accuracy:1.0000.:  89%|████████▉ | 89/100 [02:54<00:20,  1.89s/it]
#
# train loss:0.1353, train accuracy:1.0000.:  89%|████████▉ | 89/100 [02:55<00:20,  1.89s/it]
#
# train loss:0.1353, train accuracy:1.0000.:  90%|█████████ | 90/100 [02:55<00:15,  1.56s/it]
#
# train loss:0.1084, train accuracy:1.0000.:  90%|█████████ | 90/100 [02:59<00:15,  1.56s/it]
#
# train loss:0.1084, train accuracy:1.0000.:  91%|█████████ | 91/100 [02:59<00:21,  2.35s/it]
#
# train loss:0.1185, train accuracy:1.0000.:  91%|█████████ | 91/100 [03:00<00:21,  2.35s/it]
#
# train loss:0.1185, train accuracy:1.0000.:  92%|█████████▏| 92/100 [03:00<00:15,  1.97s/it]
#
# train loss:0.0735, train accuracy:1.0000.:  92%|█████████▏| 92/100 [03:01<00:15,  1.97s/it]
#
# train loss:0.0735, train accuracy:1.0000.:  93%|█████████▎| 93/100 [03:01<00:11,  1.70s/it]
#
# train loss:0.1221, train accuracy:1.0000.:  93%|█████████▎| 93/100 [03:05<00:11,  1.70s/it]
#
# train loss:0.1221, train accuracy:1.0000.:  94%|█████████▍| 94/100 [03:05<00:13,  2.20s/it]
#
# train loss:0.1188, train accuracy:1.0000.:  94%|█████████▍| 94/100 [03:06<00:13,  2.20s/it]
#
# train loss:0.1188, train accuracy:1.0000.:  95%|█████████▌| 95/100 [03:06<00:08,  1.77s/it]
#
# train loss:0.0746, train accuracy:1.0000.:  95%|█████████▌| 95/100 [03:07<00:08,  1.77s/it]
#
# train loss:0.0746, train accuracy:1.0000.:  96%|█████████▌| 96/100 [03:07<00:07,  1.81s/it]
#
# train loss:0.1205, train accuracy:1.0000.:  96%|█████████▌| 96/100 [03:11<00:07,  1.81s/it]
#
# train loss:0.1205, train accuracy:1.0000.:  97%|█████████▋| 97/100 [03:11<00:06,  2.29s/it]
#
# train loss:0.0782, train accuracy:1.0000.:  97%|█████████▋| 97/100 [03:12<00:06,  2.29s/it]
#
# train loss:0.0782, train accuracy:1.0000.:  98%|█████████▊| 98/100 [03:12<00:03,  1.93s/it]
#
# train loss:0.0673, train accuracy:1.0000.:  98%|█████████▊| 98/100 [03:13<00:03,  1.93s/it]
#
# train loss:0.0673, train accuracy:1.0000.:  99%|█████████▉| 99/100 [03:13<00:01,  1.67s/it]
#
# train loss:0.1067, train accuracy:1.0000.:  99%|█████████▉| 99/100 [03:16<00:01,  1.67s/it]
#
# train loss:0.1067, train accuracy:1.0000.: 100%|██████████| 100/100 [03:16<00:00,  1.97s/it]

# %%
############################
# train with unfreezing here (should be a single call to your train function)
############################
gc.collect()
train(start_frozen=False, model_unfreeze=20, d_set='dice')
# Out:
# Extracting dice-d4-d6-d8-d10-d12-d20-images.zip
# Resizing images in  dice-d4-d6-d8-d10-d12-d20-images
#  464
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/hub/checkpoints/resnet152-b121ed2d.pth
# HBox(children=(FloatProgress(value=0.0, max=241530880.0), HTML(value='')))
#   0%|          | 0/940 [00:00<?, ?it/s]
# 0 0
# train loss:0.3807, train accuracy:1.0000.:   5%|▌         | 47/940 [01:18<21:09,  1.42s/it]
# 0 1
# train loss:0.0645, train accuracy:1.0000.:  10%|█         | 94/940 [02:41<25:23,  1.80s/it]
# 1 2
# train loss:0.2017, train accuracy:1.0000.:  15%|█▌        | 141/940 [04:03<17:17,  1.30s/it]
# 2 3
# train loss:0.0644, train accuracy:1.0000.:  20%|██        | 188/940 [05:27<19:15,  1.54s/it]
# 3 4
# train loss:1.2986, train accuracy:0.6667.:  25%|██▌       | 235/940 [06:52<21:26,  1.83s/it]
# 4 5
# train loss:0.1524, train accuracy:1.0000.:  30%|███       | 282/940 [08:14<14:10,  1.29s/it]
# 5 6
# train loss:0.9216, train accuracy:0.6667.:  35%|███▌      | 329/940 [09:37<15:10,  1.49s/it]
# 6 7
# train loss:0.0627, train accuracy:1.0000.:  40%|████      | 376/940 [11:01<17:10,  1.83s/it]
# 7 8
# train loss:0.0130, train accuracy:1.0000.:  45%|████▌     | 423/940 [12:24<11:16,  1.31s/it]
# 8 9
# train loss:1.1720, train accuracy:0.6667.:  50%|█████     | 470/940 [13:48<11:59,  1.53s/it]
# 9 10
# train loss:1.1754, train accuracy:0.5000.:  55%|█████▌    | 517/940 [15:13<13:02,  1.85s/it]
# 10 11
# train loss:0.0331, train accuracy:1.0000.:  60%|██████    | 564/940 [16:37<08:16,  1.32s/it]
# 11 12
# train loss:0.5676, train accuracy:0.8333.:  65%|██████▌   | 611/940 [18:05<08:51,  1.62s/it]
# 12 13
# train loss:1.6186, train accuracy:0.6667.:  70%|███████   | 658/940 [19:33<09:05,  1.93s/it]
# 13 14
# train loss:0.7859, train accuracy:0.8333.:  75%|███████▌  | 705/940 [20:59<05:20,  1.36s/it]
# 14 15
# train loss:0.1227, train accuracy:1.0000.:  80%|████████  | 752/940 [22:27<04:55,  1.57s/it]
# 15 16
# train loss:0.6294, train accuracy:0.6667.:  85%|████████▌ | 799/940 [23:55<04:28,  1.90s/it]
# 16 17
# train loss:0.1830, train accuracy:0.8333.:  90%|█████████ | 846/940 [25:21<02:07,  1.36s/it]
# 17 18
# train loss:1.1158, train accuracy:0.6667.:  95%|█████████▌| 893/940 [26:50<01:15,  1.61s/it]
# 18 19
# train loss:1.6470, train accuracy:0.5000.: 100%|██████████| 940/940 [28:19<00:00,  1.81s/it]

# %% [markdown]
# You may not see any improvement for your classification task, but unfreezing can help convergence for more difficult image classification tasks.

# %% [markdown]
# ##2 Fine-tune a language model - (15 min)

# %% [markdown]
# In this section you will use the gpt-2-simple package [here](https://github.com/minimaxir/gpt-2-simple) to fine-tune the GPT-2 language model on a domain of your choice.

# %% [markdown]
# ### 2.1 Generate text from an the pretrained GPT-2 model

# %% [markdown]
# #### Run this code to generate text from a pretrained model

# %%
# !pip install gpt-2-simple

# the transformers package is built on top of Tensorflow, and the default TF version 
# for Colab will soon switch to 2.x. We remedy this with the following magic method
# %tensorflow_version 1.x 

import gpt_2_simple as gpt2
import os
import tensorflow as tf
import gc
# Out:
# Collecting gpt-2-simple
#   Downloading https://files.pythonhosted.org/packages/6f/e4/a90add0c3328eed38a46c3ed137f2363b5d6a07bf13ee5d5d4d1e480b8c3/gpt_2_simple-0.7.1.tar.gz
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.18.5)
# Collecting toposort
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2020.6.20)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.1-cp36-none-any.whl size=23581 sha256=5104083e0dd698d127ea7a27b069f86d2d7bde147dc5ee5f90972c5d594f0c12
#   Stored in directory: /root/.cache/pip/wheels/0c/f8/23/b53ce437504597edff76bf9c3b8de08ad716f74f6c6baaa91a
# Successfully built gpt-2-simple
# Installing collected packages: toposort, gpt-2-simple
# Successfully installed gpt-2-simple-0.7.1 toposort-1.5
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# This line is necessary to be able to run a new tf session
gc.collect()
tf.reset_default_graph()
# The medium-sized model. IF you run out of memory, try "124M" instead
model_name = "124M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/

sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, model_name=model_name)
gpt2.generate(sess, model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 460Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 85.4Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 351Mit/s]
# Fetching model.ckpt.data-00000-of-00001:   0%|                          | 0.00/498M [00:00<?, ?it/s]
# Downloading 124M model...
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:04, 116Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 395Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 184Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 170Mit/s]
# Loading pretrained model models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# A review of the government's data and interventions in the financial sector highlights the extent to which the government's legacy of strong fiscal policies has been undermined by the magnitude of the shortfall.
#
# The government's 2007 fiscal stimulus package did not include the multi-billion dollar tax cuts enacted under the Bill of Rights.
#
# The government has said that it will increase tax revenues by 8.2 per cent over the next decade and may also increase balance sheets by 1.8 per cent.
#
# The government has also reported a 0.1 per cent rise in long-term debt in the year to March.
#
# The remaining deficit in the year to March was $18.3 billion, largely due to a shortfall in the government's financial services funding program, which was $3.1 billion.
#
# The government's fiscal projections include a deficit of 9.6 per cent of GDP in the last quarter of this year.
#
# This was the first time in the government's 23-year history that the deficit had been more than 9 per cent of GDP.
#
# The government has said it will cut back on spending and put its finances on a more sustainable footing.
#
# The government's fiscal outlook includes a 5 per cent fall in the debt to GDP ratio while the debt to inflation ratio is expected to remain very low.
#
# The government's debt to GDP ratio is projected to rise from 7.3 per cent to 7.9 per cent of GDP in the year to March.
#
# Topics: finance, government-and-politics, australia, sydney-2000, sydney-2000-0329
#
# First posted<|endoftext|>The North Korean government has barred US-based analysts and journalists from visiting North Korea, two American and three European sources said on Saturday.
#
# North Korean state media said North Korea has fired back with a wave of threats.
#
# The US-based analysts who visited North Korea, sources told Reuters, were banned from visiting the country after they refused to follow US sanctions imposed on Pyongyang on Monday.
#
# The US sanctions, which have been lifted following a UN Security Council resolution, have been suspended since last week.
#
# North Korea, which has a 1950-old nuclear weapons programme, said on Saturday that it would retaliate by launching nuclear warheads on its neighbour.
#
# The North had previously threatened to strike the US mainland with more nuclear tests by the end of the year.
#
# One of the seven American and European sources said the North was planning to launch an attack on the US in the coming days.
#
# "We think it will be launched from a position of strength, but we don't have specific details. It's likely that the US is going to launch a nuclear launch on the North," one of the sources told Reuters.
#
# The US state department said the North had launched the first strike on a US ship in recent years on September 30, while the ship was carrying a US nuclear-tipped missile.
#
# Officials said the North had also launched a long-range missile on September 30.
#
# "The key objective is to send a strong message to the US that it is not ready for a nuclear attack," said State Department spokesman John Kirby.
#
# North Korea has repeatedly denied any such attacks, saying its nuclear weapons are purely to deter attack.
#
# Earlier in the day, the North's state news agency said it had launched a missile that landed in the isolated country's southwestern hospital it said was carrying the American flag.
#
# American and European diplomats were in Pyongyang on Saturday to meet with North Korean leaders to discuss the looming consequences of the sanctions, which imposed new sanctions on Pyongyang for its nuclear and ballistic missile programmes.<|endoftext|>Gangster's Management is currently planning on wrapping up another round of development, this time the first of its kind in the country.
#
# The 2.5-acre development will be a long-term project, with an average of eight to eight years of development, according to the GLC Group, which is a consortium of international companies that include Pinnacle Construction, Ford Motor Company, The New York Giants and Citigroup.
#
# The project is expected to be a mixed bag as it focuses on the residential, commercial, industrial, retail and residential sectors.
#
# GLC Group is one of a number of companies on the ground in South Korea, with projects in the city of Seoul, South Korea, and Nankong-gu, Nankong-gu, South Korea. The GLC Group is a joint venture between GLC Group, GLC Construction, GLC Capital & Partners and Samsung Electronics Co., Ltd.
#
# GLC Group – who have also been building residential and commercial buildings in South Korea – last started construction on Wed. 26, 2014 for the first phase of the GLC Group's residential residential project in Naoyang, S.T. (62.9 km south-east of Seoul), Reuters reported.
#
# The project will include a 1,100-square-meter building,

# %% [markdown]
# ### 2.2 Download a text dataset

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Use the provided functions to download your own text dataset
# - [Project Gutenberg](https://www.gutenberg.org/) is a nice starting point for raw text corpora

# %% [markdown]
# #### Download Dataset

# %%
import zipfile
import os
from torchvision import datasets

def extract_zip(zip_path, remove_finished=True):
    print('Extracting {}'.format(zip_path))
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(zip_path.replace('.zip', ''))
    if remove_finished:
        os.remove(zip_path)

def download_dataset(url, root='../data'):
    if not os.path.exists(os.path.join(root, 'text')):
        os.makedirs(os.path.join(root))
        datasets.utils.download_url(url, root, 'text.zip', None)
        extract_zip(os.path.join(root, 'text.zip'))
    return os.path.join(root, 'text')

##########################################
# Set the url for your dataset here,
# move the dataset to the desired location
##########################################
# url = 'https://www.gutenberg.org/files/30/30.zip'
url = 'https://www.gutenberg.org/files/50133/50133-8.zip'
download_dataset(url)
# !mv /data/text/30.txt /data/text/lovecraft.txt #/data/text/bible.txt
# !mv /data/text/50133-8.txt /data/text/lovecraft.txt
# !ls ../data/text
# Out:
# lovecraft.txt

# %% [markdown]
# ### 2.3 Fine-tune GPT-2 on your own dataset

# %% [markdown]
# #### TODO:

# %% [markdown]
# - Swap out the dataset parameter with the path to your dataset

# %% [markdown]
# #### Train on your dataset

# %%
# This line is necessary to be able to run a new tf session if one has already been run
tf.reset_default_graph()
# Start a session
sess = gpt2.start_tf_sess()
# Fine tune `model_name` on `data`
###################################
# Swap out the `dataset` parameter with the path to your text dataset
###################################
gpt2.finetune(sess,
              dataset='../data/text/lovecraft.txt',
              model_name=model_name,
              restore_from='latest',
              steps=500)   # steps is max number of training steps

gpt2.generate(sess, run_name='run1')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# dataset has 30329 tokens
# Training...
# [1 | 8.72] loss=4.19 avg=4.19
# [2 | 10.89] loss=3.59 avg=3.89
# [3 | 13.06] loss=3.95 avg=3.91
# [4 | 15.24] loss=3.79 avg=3.88
# [5 | 17.41] loss=3.44 avg=3.79
# [6 | 19.59] loss=3.82 avg=3.80
# [7 | 21.77] loss=2.62 avg=3.62
# [8 | 23.95] loss=3.61 avg=3.62
# [9 | 26.13] loss=3.06 avg=3.56
# [10 | 28.32] loss=2.52 avg=3.45
# [11 | 30.51] loss=3.09 avg=3.41
# [12 | 32.70] loss=3.57 avg=3.43
# [13 | 34.90] loss=3.63 avg=3.44
# [14 | 37.09] loss=3.40 avg=3.44
# [15 | 39.29] loss=2.76 avg=3.39
# [80 | 185.95] loss=1.32 avg=2.03
# [81 | 188.25] loss=0.78 avg=2.00
# [82 | 190.54] loss=1.18 avg=1.99
# [83 | 192.83] loss=0.60 avg=1.96
# [84 | 195.13] loss=0.77 avg=1.94
# [85 | 197.43] loss=0.38 avg=1.92
# [86 | 199.73] loss=1.02 avg=1.90
# [87 | 202.02] loss=0.49 avg=1.88
# [88 | 204.32] loss=0.84 avg=1.86
# [89 | 206.62] loss=0.55 avg=1.84
# [90 | 208.93] loss=0.64 avg=1.82
# [91 | 211.22] loss=0.65 avg=1.80
# [92 | 213.53] loss=0.58 avg=1.78
# [93 | 215.83] loss=0.68 avg=1.76
# [94 | 218.14] loss=0.63 avg=1.74
# [95 | 220.45] loss=0.75 avg=1.72
# [96 | 222.75] loss=0.63 avg=1.71
# [97 | 225.06] loss=0.44 avg=1.69
# [98 | 227.36] loss=0.46 avg=1.67
# [99 | 229.66] loss=0.44 avg=1.65
# [100 | 231.97] loss=0.35 avg=1.63
# ======== SAMPLE 1 ========
# .
# his eyes moved with a peculiar
# blasphemously keenness found in his pinky-whippoorwills. It was on that awful afternoon
# that he finally set out again, this time without a party of hero, for
# sheila he had her Elmer Fudd slave on his hard, dark
# hiding in the glens so frightfully covered he could scarcely walk
# shrewd.
#
# On the morning of May twincoment the boy's death, a frightful
# horror-filled whole section of the household was kept from reading
# by acclamation or sleep. The only light-digging went on at
# The Wizarding World, whence strange impressions of � offrush
# rush-rush-rush-rush-rush-rush-rush-rush-rush-
# brings down images of primal, terrible mental terrors. Deep-seated
# monstrosities with gaping eyes and hoarse orgies of
# whippoorwions were watching the strange boy, and those wonders
# had virtually caused the horror to begin. The watcher--a
# retired boy of about ten whose thick lips and ageless
# voice gave every ear a twisted "o"--was finally allowed to
# talk on the spot; and in the course of time his gait and
# goaty afghans had somewhat calmed.
#
# In the meantime the watcher had something of a reputation as being kind
# regarded even by those who had once witnessed it. He would sometimes
# give some tell-all to correspondent Sally Blanchflower, who had once
# gone by in a car and checked himself into it for the first time.
# "Mr. Whateley," she would say, "I thought he looked like
# him.''
#
# But since then Wilbur had come a lot closer. At the ancient, low,
# nonlinear end of the Yucatan Peninsula there were stretches of country once
# heavily marked out and confidently mapped; stretches which, once
# hearings, now stretch between country and sky, and prove, once and
# for all, to be an impracticable game.
#
# "There he was last Saturday, gasping hysterically for air, as a frighted-out
# daughter-in-law sobbed in the street. Another frightened-of-the-moments
# moments of panic followed; and then the Wilburians burst into
# response with monstrous screaming and street-corner-mass murders. The
# plain old man in the pulpit screamed back at the women:
# "Get on the line, motherf--ker! ... The Whateleys--they had better go--their throats werena cut!
# They could've leeted everybody or something, but we the People fought so hard
# that only a Two-Face can save a thing! Everybody gets on the line, boys!"
#
# Then Wilbur turned toward the camera and paused, as though in thought of
# contempt. "You little fellows, just because--just because--They put a stop to
# the thing--because they thought it would save lives?"
#
# He paused again, though this time he said a little prayer over the megaphone.
# These were the sorts of things that might make one think--at least, to some
# degree--that a race for the hills were on the wane. That, however,
# did not apply to the villagers. Three days before Mr. Wilbur
# had told the press that the world hated him because of his
# greenish-tinge ways and lamented his passing, a large crowd of _--strangers
# with him at the time--strided over the road and hear what they think
# his last words would be. Of course--well, there are certain _things_ that _are_ _things.
# These people, after all, shunned Wilbur for many reasons; many of which he
# did not even bother to address. Some of them even tried to extort large
# doll-parts from him on the farmhouse-goinish, or Pekingese, level-bearer. Some
# refused to take responsibility for the fall of the village and of the Zebulon horror
# academies, while others maintained that he would never have committed
# such an atrocity had he lived. No, really, this man kept on putting
# himself in Oppenheimer's business, and was indeed hired that week
# as field marshal near Aylesbury. Himmler, being the tough, bearded,
# aggressive boy he was, began to pore over the _outsidear_'s _caught-all_ notes
# he had left at Oppenheimer's. His task was simple--he picked
# up up every page and linked it to the one he had left, restoring it
# to some semblance of its former nameless, unaltered state. It was
#
# [101 | 246.99] loss=0.36 avg=1.61
# [102 | 249.30] loss=0.34 avg=1.59
# [103 | 251.60] loss=0.32 avg=1.57
# [104 | 253.91] loss=0.41 avg=1.55
# [105 | 256.22] loss=0.26 avg=1.53
# [106 | 258.53] loss=0.25 avg=1.51
# [107 | 260.85] loss=0.42 avg=1.49
# [108 | 263.16] loss=0.33 avg=1.48
# [109 | 265.48] loss=0.26 avg=1.46
# [110 | 267.78] loss=0.20 avg=1.44
# [111 | 270.09] loss=0.40 avg=1.42
# [112 | 272.40] loss=0.17 avg=1.41
# [113 | 274.71] loss=0.21 avg=1.39
# [114 | 277.03] loss=0.21 avg=1.37
# [115 | 279.34] loss=0.19 avg=1.35
# [116 | 281.66] loss=0.23 avg=1.34
# [117 | 283.97] loss=0.26 avg=1.32
# [118 | 286.29] loss=0.17 avg=1.30
# [119 | 288.60] loss=0.19 avg=1.29
# [120 | 290.92] loss=0.13 avg=1.27
# [121 | 293.23] loss=0.19 avg=1.26
# [122 | 295.55] loss=0.15 avg=1.24
# [123 | 297.87] loss=0.17 avg=1.23
# [124 | 300.18] loss=0.22 avg=1.21
# [125 | 302.51] loss=0.22 avg=1.20
# [126 | 304.83] loss=0.07 avg=1.18
# [127 | 307.16] loss=0.20 avg=1.17
# [128 | 309.47] loss=0.11 avg=1.15
# [129 | 311.80] loss=0.11 avg=1.14
# [130 | 314.12] loss=0.11 avg=1.13
# [131 | 316.45] loss=0.10 avg=1.11
# [132 | 318.77] loss=0.18 avg=1.10
# [133 | 321.09] loss=0.13 avg=1.09
# [134 | 323.42] loss=0.10 avg=1.07
# [135 | 325.75] loss=0.10 avg=1.06
# [136 | 328.07] loss=0.24 avg=1.05
# [137 | 330.40] loss=0.12 avg=1.04
# [138 | 332.73] loss=0.11 avg=1.02
# [139 | 335.06] loss=0.11 avg=1.01
# [140 | 337.38] loss=0.07 avg=1.00
# [141 | 339.71] loss=0.11 avg=0.99
# [142 | 342.04] loss=0.10 avg=0.98
# [143 | 344.37] loss=0.13 avg=0.96
# [144 | 346.70] loss=0.06 avg=0.95
# [145 | 349.02] loss=0.08 avg=0.94
# [146 | 351.36] loss=0.24 avg=0.93
# [147 | 353.68] loss=0.11 avg=0.92
# [148 | 356.02] loss=0.10 avg=0.91
# [149 | 358.35] loss=0.11 avg=0.90
# [150 | 360.68] loss=0.10 avg=0.89
# [151 | 363.01] loss=0.11 avg=0.88
# [152 | 365.34] loss=0.12 avg=0.87
# [153 | 367.67] loss=0.08 avg=0.86
# [154 | 370.00] loss=0.07 avg=0.85
# [155 | 372.33] loss=0.08 avg=0.84
# [156 | 374.66] loss=0.07 avg=0.83
# [157 | 376.99] loss=0.10 avg=0.82
# [158 | 379.32] loss=0.10 avg=0.81
# [159 | 381.65] loss=0.10 avg=0.80
# [160 | 383.98] loss=0.08 avg=0.79
# [161 | 386.31] loss=0.07 avg=0.79
# [162 | 388.64] loss=0.05 avg=0.78
# [163 | 390.97] loss=0.07 avg=0.77
# [164 | 393.31] loss=0.09 avg=0.76
# [165 | 395.64] loss=0.07 avg=0.75
# [166 | 397.97] loss=0.08 avg=0.74
# [167 | 400.30] loss=0.07 avg=0.73
# [168 | 402.63] loss=0.11 avg=0.73
# [169 | 404.97] loss=0.08 avg=0.72
# [170 | 407.30] loss=0.08 avg=0.71
# [171 | 409.63] loss=0.09 avg=0.70
# [172 | 411.96] loss=0.08 avg=0.70
# [173 | 414.30] loss=0.08 avg=0.69
# [174 | 416.64] loss=0.08 avg=0.68
# [175 | 418.98] loss=0.10 avg=0.67
# [176 | 421.32] loss=0.05 avg=0.67
# [177 | 423.66] loss=0.08 avg=0.66
# [178 | 425.99] loss=0.07 avg=0.65
# [179 | 428.33] loss=0.12 avg=0.65
# [180 | 430.67] loss=0.07 avg=0.64
# [181 | 433.01] loss=0.08 avg=0.63
# [182 | 435.36] loss=0.07 avg=0.63
# [183 | 437.70] loss=0.05 avg=0.62
# [184 | 440.04] loss=0.06 avg=0.61
# [185 | 442.38] loss=0.06 avg=0.61
# [186 | 444.72] loss=0.08 avg=0.60
# [187 | 447.05] loss=0.06 avg=0.59
# [188 | 449.39] loss=0.08 avg=0.59
# [189 | 451.73] loss=0.08 avg=0.58
# [190 | 454.07] loss=0.06 avg=0.57
# [191 | 456.41] loss=0.05 avg=0.57
# [192 | 458.75] loss=0.05 avg=0.56
# [193 | 461.08] loss=0.07 avg=0.56
# [194 | 463.42] loss=0.07 avg=0.55
# [195 | 465.76] loss=0.06 avg=0.55
# [196 | 468.09] loss=0.07 avg=0.54
# [197 | 470.43] loss=0.07 avg=0.53
# [198 | 472.77] loss=0.06 avg=0.53
# [199 | 475.11] loss=0.10 avg=0.52
# [200 | 477.45] loss=0.05 avg=0.52
# ======== SAMPLE 1 ========
#
# pursue
#       which
#         is this? _this horror_ after breakfast?--"
#        he trailed off, but another moment or two
#       produced olfactory brimming with anticipation. "_"
#       looked at the floor with interest, and his
#       final utterance came with a wave of violence and disgust.
#
# "_That's it, boys! It's a-goin' its own path! It's a-goin' its own path
#      to the left of here; it's a-goin' its own path--but it
#      has to. We must follow it, and the more we do, the
#      more we'll find it. It grows fast, grows strong,
#     can't tread without our permission; but if we
#      follow it, it'll follow us wherever we go.
#
# "I tell ye, Col. Armitage, that we may go small--small as
#      can be. Not small as we are, but very Japanese in
#      ways. We must follow it, and the more we do, the
#      more we'll find it. It grows fast, grows strong,
#      can't tread without our permission; but if we
#      follow it, it'll follow us wherever we go.
#
# "I tell ye, Col. Armitage, that we may go home again--a fresh start
#       in finding out what is really going on--but a fresh start
#       in seeing--willing to be found in it--helping to make it
#       a reality, no? You know what that might do? Help it
#       to grow back into a kind of being which was once its
#       parentage, and which is now its new parentage?
#       like? It would be better off--if we could--but there
#       is enough. We must follow it, and the more we do, the
#       better it is. It grows fast, grows strong, can't tread without our
#       permission, and can't be without our permission at least for a moment.
#
# "But what if--if--it were possible--that all the children of Essene should
#      live together again, and be raised by the same father? That would be a big
#      change, wouldn't it? Only this: they'd be one people. The
#      old people after them. They were born again--but they this very minute.
#      they were as good as their father in every respect. They stood by
#      the new creation--but were they to one day stand a chance of
#     developing a common father and mother? They weren't very good
#     acers--only just. They were very, very dark, awful, awful
#     at times--but at least they weren't like their father--was
#     what it is to be human--a horrible, horrible part of it.
#     the old gods had it really good, that by some foulness
#     act of nature they should have it so bad, that there is nothing
#     humanly a human being capable of.
#     they did, and they are as bad as any human evil._
#     humans are ineffable--inexorable only because of some
#     complex in the brain which knows no difference between good and evil,
#     and doesn't exist an either/or kind._
#     they are like the clouds in the sky--dim and vast--which do not
#     appear to be clouds, but appear to be a kind of indescribable
#      mistiness about which neither the human mind nor the human
#     clouds think a responsibility. After all, what
#     cloud thinks of the human man when he sees a castle silhouetted by
#     sunshine and ringside? After all, what man, without the human
#     intelligence, could think of seeing such a thing? After all, what
#     cloud would feel a responsibility to look at such a sight, even when
#     the man is within earshot of it? After all, what
#     man would be justified in believing without a doubt to be false
#     knowledge? _
#
# [201 | 491.79] loss=0.06 avg=0.51
# [202 | 494.12] loss=0.06 avg=0.51
# [203 | 496.45] loss=0.06 avg=0.50
# [204 | 498.78] loss=0.06 avg=0.50
# [205 | 501.12] loss=0.05 avg=0.49
# [206 | 503.46] loss=0.06 avg=0.49
# [207 | 505.80] loss=0.05 avg=0.48
# [208 | 508.15] loss=0.04 avg=0.48
# [209 | 510.49] loss=0.05 avg=0.47
# [210 | 512.83] loss=0.07 avg=0.47
# [211 | 515.17] loss=0.05 avg=0.46
# [212 | 517.52] loss=0.06 avg=0.46
# [213 | 519.86] loss=0.05 avg=0.45
# [214 | 522.20] loss=0.06 avg=0.45
# [215 | 524.55] loss=0.05 avg=0.45
# [216 | 526.89] loss=0.05 avg=0.44
# [217 | 529.22] loss=0.06 avg=0.44
# [218 | 531.56] loss=0.06 avg=0.43
# [219 | 533.90] loss=0.07 avg=0.43
# [220 | 536.25] loss=0.07 avg=0.42
# [221 | 538.60] loss=0.05 avg=0.42
# [222 | 540.94] loss=0.06 avg=0.42
# [223 | 543.28] loss=0.05 avg=0.41
# [224 | 545.62] loss=0.07 avg=0.41
# [225 | 547.96] loss=0.07 avg=0.40
# [226 | 550.31] loss=0.05 avg=0.40
# [227 | 552.64] loss=0.04 avg=0.40
# [228 | 554.98] loss=0.06 avg=0.39
# [229 | 557.31] loss=0.06 avg=0.39
# [295 | 712.12] loss=0.04 avg=0.22
# [296 | 714.46] loss=0.04 avg=0.22
# [297 | 716.81] loss=0.05 avg=0.21
# [298 | 719.16] loss=0.05 avg=0.21
# [299 | 721.51] loss=0.05 avg=0.21
# [300 | 723.86] loss=0.05 avg=0.21
# ======== SAMPLE 1 ========
#
# The Whateleys had
# been shockingly terrorsque to discover, and some trace of their birth
# race, sex, and ancestry is to be found in several closely related
# quaint families.
#
# According to legends and conjectures long passed through the regions, Dunwich was
# built of very solid earth, of which the most ancient and least
# brave of the Dunwich fires had been the massacre at the
# Old Vicarage in 1928, when a party of armed bandits besiege it
# for three days at one end, freezing to death in their tracks after
# drenching the ground with a coarse black drenching-torching upon entry. The
# steep incline that one got in allowed one through the upper reaches
# of the chilling chamber, and through the peaked gatehouse the steep slope
# seemed like it had an infinity of ages of ills. At other
# times it was rough torrential downpour, with lots of specks of
# bog-bling, bar'leighs, and yells of "enough!" followed by a flash of yellow
# fleshing pansorama figures raising their arms in the vain hope of
# saving the day.
#
# "Oh, my Gawd, that Col' Spring Glen is aaming crumpled up like the
# hogsmeared Lamb Chappell--a crumpled-up altar-chappell like the one that
# made the sign for Whateley's altar, and like the Lamb's swish to and fro in
# the same fashion. Unsinkable as the cursed altar may be, it is
# too late to make the same impression on the human race. They are
# taughters in no school, and must take up their training at
# Old Whateley's. Passing through the gates one would think they
# would be confronted with a race of highly paid visitors--but no
# visitors are thought to be loading or unloading anything into or out of the
# thing; only the barking and the screaming make mind to beamed back
# when fully equipped. It is hard to tell how many--if any--of the
# customers there are, but they say and feel that it is a windy day
# day's labour upon the part of the people in blowing mighty wind
# off the hills to the southward. Those who do so are quickly shot and
# stunned by the crowd of State Police, who, despite repeated
# beneath a would-be assassin's trail, still huddled still tighter and
# dare longer than ever. The ground below them is covered in a coarse,
# terrible crescent that glows with an abnormal variation in the
# degree of yellow and purple that appear on the wings when the ground is covered
# with them. The watchers say that one of the dogs on the watchbills is
# raising his arms in the strange rhythmic motion of its long, shining
# blade. Then it abounds with a report of a loud, crashing,
# faint, barrel-like noise which echoes diabolically from the hilltops,
# and from various places across the country. The abandoned Whateley farmhouse
# in Fordsbord, in the far northernmost section of the State
# annex, was once the scene of a frightful and unexplained horror.
# Now, then, is the right time to call the attention of the police?
# The restoration of the Whateley house came at a terrible cost; and the
# imperfective
# existence of the squalid
# prostitute quarters made the ruins of the property more and more
# watched and feared than any of their members. Neighbors saw through
# the grapevine that one of the sons of Manley, an unpossessed
# slave-like figure among the rough-hewn ruins, was going
# around the rough-hewn side of the old farmhouse in search of some
# damn old iglindrome or diabolical experiment with electricity.
#
# One evening, just as the party had departed, they all went to bed; but
# the next day there was a fright-mad waking that brought no rest; and
# it was not long before officers from the State Department,
# and from elsewhere in the government, were conducting field sweeps and field
# sniping at the ruined base of the old Whateley mountain. The
# moving mountains, with their varied and sometimes shockingly clear sky, made
# for a really frightful sight, and filled the night with a kind of panic
# that belied the fact that there was nothing more to be
# seen. When the officers left, they found them in a fright that lasted only
# a moment, and were shared with the curious spectacle on the
# base of the old mountain.
#
# It was in that instant that the worst of the disorder subsided, and
# a great tidal wave of destruction swept down from the sky. Trees, grass,
# and underbrush were whipped into
#
# [301 | 738.16] loss=0.04 avg=0.21
# [302 | 740.50] loss=0.05 avg=0.21
# [303 | 742.84] loss=0.05 avg=0.20
# [304 | 745.17] loss=0.04 avg=0.20
# [305 | 747.51] loss=0.05 avg=0.20
# [306 | 749.84] loss=0.04 avg=0.20
# [307 | 752.18] loss=0.05 avg=0.20
# [308 | 754.52] loss=0.04 avg=0.20
# [309 | 756.86] loss=0.04 avg=0.19
# [310 | 759.19] loss=0.05 avg=0.19
# [311 | 761.53] loss=0.04 avg=0.19
# [312 | 763.87] loss=0.05 avg=0.19
# [313 | 766.21] loss=0.04 avg=0.19
# [314 | 768.55] loss=0.04 avg=0.19
# [315 | 770.89] loss=0.04 avg=0.18
# [316 | 773.23] loss=0.04 avg=0.18
# [317 | 775.57] loss=0.05 avg=0.18
# [318 | 777.91] loss=0.05 avg=0.18
# [319 | 780.25] loss=0.05 avg=0.18
# [320 | 782.59] loss=0.04 avg=0.18
# [321 | 784.92] loss=0.05 avg=0.18
# [322 | 787.27] loss=0.05 avg=0.18
# [323 | 789.62] loss=0.04 avg=0.17
# [324 | 791.97] loss=0.05 avg=0.17
# [325 | 794.31] loss=0.03 avg=0.17
# [326 | 796.65] loss=0.04 avg=0.17
# [327 | 798.99] loss=0.05 avg=0.17
# [328 | 801.32] loss=0.05 avg=0.17
# [329 | 803.67] loss=0.04 avg=0.17
# [330 | 806.01] loss=0.04 avg=0.16
# [331 | 808.36] loss=0.05 avg=0.16
# [332 | 810.70] loss=0.05 avg=0.16
# [333 | 813.04] loss=0.05 avg=0.16
# [334 | 815.39] loss=0.05 avg=0.16
# [335 | 817.74] loss=0.05 avg=0.16
# [336 | 820.09] loss=0.04 avg=0.16
# [337 | 822.44] loss=0.04 avg=0.16
# [338 | 824.79] loss=0.06 avg=0.15
# [339 | 827.13] loss=0.04 avg=0.15
# [340 | 829.47] loss=0.04 avg=0.15
# [341 | 831.82] loss=0.05 avg=0.15
# [342 | 834.16] loss=0.04 avg=0.15
# [343 | 836.51] loss=0.03 avg=0.15
# [344 | 838.85] loss=0.04 avg=0.15
# [345 | 841.20] loss=0.05 avg=0.15
# [346 | 843.55] loss=0.05 avg=0.15
# [347 | 845.90] loss=0.05 avg=0.14
# [348 | 848.26] loss=0.04 avg=0.14
# [349 | 850.60] loss=0.04 avg=0.14
# [350 | 852.95] loss=0.05 avg=0.14
# [351 | 855.29] loss=0.04 avg=0.14
# [352 | 857.63] loss=0.04 avg=0.14
# [353 | 859.98] loss=0.05 avg=0.14
# [354 | 862.32] loss=0.05 avg=0.14
# [355 | 864.67] loss=0.05 avg=0.14
# [356 | 867.01] loss=0.04 avg=0.14
# [357 | 869.35] loss=0.05 avg=0.14
# [358 | 871.69] loss=0.04 avg=0.13
# [359 | 874.03] loss=0.04 avg=0.13
# [360 | 876.38] loss=0.05 avg=0.13
# [361 | 878.73] loss=0.05 avg=0.13
# [362 | 881.08] loss=0.04 avg=0.13
# [363 | 883.43] loss=0.04 avg=0.13
# [364 | 885.78] loss=0.04 avg=0.13
# [365 | 888.12] loss=0.06 avg=0.13
# [366 | 890.47] loss=0.05 avg=0.13
# [367 | 892.82] loss=0.05 avg=0.13
# [368 | 895.17] loss=0.04 avg=0.13
# [369 | 897.51] loss=0.04 avg=0.12
# [370 | 899.86] loss=0.05 avg=0.12
# [371 | 902.21] loss=0.05 avg=0.12
# [372 | 904.56] loss=0.03 avg=0.12
# [373 | 906.91] loss=0.04 avg=0.12
# [374 | 909.26] loss=0.03 avg=0.12
# [375 | 911.61] loss=0.04 avg=0.12
# [376 | 913.96] loss=0.04 avg=0.12
# [377 | 916.31] loss=0.06 avg=0.12
# [378 | 918.65] loss=0.04 avg=0.12
# [379 | 921.00] loss=0.04 avg=0.12
# [380 | 923.35] loss=0.04 avg=0.12
# [381 | 925.70] loss=0.04 avg=0.11
# [382 | 928.05] loss=0.04 avg=0.11
# [383 | 930.40] loss=0.04 avg=0.11
# [384 | 932.74] loss=0.04 avg=0.11
# [385 | 935.08] loss=0.05 avg=0.11
# [386 | 937.42] loss=0.04 avg=0.11
# [387 | 939.76] loss=0.05 avg=0.11
# [388 | 942.11] loss=0.03 avg=0.11
# [389 | 944.46] loss=0.04 avg=0.11
# [390 | 946.81] loss=0.03 avg=0.11
# [391 | 949.16] loss=0.06 avg=0.11
# [392 | 951.50] loss=0.04 avg=0.11
# [393 | 953.86] loss=0.05 avg=0.11
# [394 | 956.20] loss=0.05 avg=0.11
# [395 | 958.55] loss=0.04 avg=0.11
# [396 | 960.90] loss=0.04 avg=0.10
# [397 | 963.25] loss=0.04 avg=0.10
# [398 | 965.60] loss=0.04 avg=0.10
# [399 | 967.95] loss=0.04 avg=0.10
# [400 | 970.30] loss=0.04 avg=0.10
# ======== SAMPLE 1 ========
#  the party at
#     this table for some reason or another hath failed to transmit the
#     answer it had received. It being this duty of the
#     court to make known the findings of fact and to instruct the
#     defensive step required when approaching a conclusion concerning a liability
#      of this kind. The more difficult it is to obtain a definite
#      answer from the party who did commit the felony, the safer it is to
#      try to make the assumption that the other party did not commit the
#      felony.
#
# "But this is a country instrument; it is a double staunchest
#      curse that confers forever upon us all, and we are egotically
#      bound to those same earth-forms and inner entities that are to be
#      the property and communication of those outer spheres. They, too,
#     are born of fate, and are heirless to the conditions of mankind
#     whose nature and form and substance are almost like our own; and
#     who are they to us? The ancient gods, the QI
#     races, the demons, the witch-doers, the iniquities of old Wilbur
#     and all the other eternities which have ruled us since infancy--these are
#     the laws of our period, and must be abandoned without a second
#     look at them from eternity, for they are the laws of this planet.
#
# Mr. Hoadley disappeared soon after delivering this sermon; so we do not
#     know where he is or what he is doering here. He may be
#     busy in loading up his things, but he can not see
#     us without our permission. He may be thinking of some
#     action which he may do as soon as he utters that word
#     and his action is just. He may rob us all of our
#     blessings, and to them we shall never know.
#
# Lines of reasoning in the sermon were
#     tough being drawn between what was obvious and what was
#     false, and Dr. Hoadley concluded that the message to be
#     true was one man's guess, but he proved it to be
#     true to an infinite variety of lengths of lengths of lengths of lengths of
#     lengths. He needed to know the township where we left off, and
#     he did not appear till we left.
#
# As we must know, the next day there was a fright-mad crowd at
#     the house; all officers and servants having been summoned
#     to disperse along the line; but all were violently
#     whipped and kicked out the window. The governor and
#     the populace stood by to watch, but were evidently alarmed because
#     a great crowd of people had been being led out by a sharp archway and
#     a great party of policemen and firemen had been summoned. The
#     streets are deserted, and party men and policemen stand by
#     wondering at the strange sight where the blow had been struck.
#     It was always somewhat after this time that the whippoorwills
#     began to shriek, and there is a sense in which the atmosphere might
#     been more voluminous and audible. Government buildings now
#     have been erected on the banks where the noise has been vocal;
#     where the whirlwinds of the airships have echoed without blemish; and
#     where the great chorus of birds has continued unabated since
#
#     at the Whateley place.
#
# Those memories shall never leave us; they are haff-shaped in the
#     air of being terrors to us all, and we mustn't look
#     at the wraparound horror we've formed from the noise of their
#     destruction.
#
# The next day all the countryside was in a panic; and
#     officials from the government were summoned at once to see who might
#     be among the many types of whippoorwills which have been so strangely
#     noticed during the last month; and the whippoorwills of Wilbur
#     are among them. It was the custom at Wilbur that
#     all wannabes were sent to the hamlet, and every house
#     was required to have a lock and key on file at the central
#     place. The whippoorwills, in general, were very grave
#     and terminated in pits about
#
# [401 | 984.64] loss=0.04 avg=0.10
# [402 | 986.99] loss=0.05 avg=0.10
# [403 | 989.33] loss=0.04 avg=0.10
# [404 | 991.68] loss=0.03 avg=0.10
# [405 | 994.02] loss=0.04 avg=0.10
# [406 | 996.37] loss=0.05 avg=0.10
# [407 | 998.72] loss=0.03 avg=0.10
# [408 | 1001.06] loss=0.04 avg=0.10
# [409 | 1003.40] loss=0.04 avg=0.10
# [410 | 1005.74] loss=0.04 avg=0.10
# [411 | 1008.08] loss=0.04 avg=0.10
# [412 | 1010.42] loss=0.03 avg=0.09
# [413 | 1012.77] loss=0.05 avg=0.09
# [414 | 1015.11] loss=0.04 avg=0.09
# [415 | 1017.45] loss=0.05 avg=0.09
# [416 | 1019.79] loss=0.04 avg=0.09
# [417 | 1022.14] loss=0.05 avg=0.09
# [418 | 1024.48] loss=0.04 avg=0.09
# [419 | 1026.83] loss=0.04 avg=0.09
# [420 | 1029.17] loss=0.03 avg=0.09
# [421 | 1031.52] loss=0.04 avg=0.09
# [422 | 1033.86] loss=0.04 avg=0.09
# [423 | 1036.21] loss=0.05 avg=0.09
# [424 | 1038.54] loss=0.05 avg=0.09
# [425 | 1040.88] loss=0.04 avg=0.09
# [426 | 1043.22] loss=0.05 avg=0.09
# [427 | 1045.57] loss=0.04 avg=0.09
# [428 | 1047.90] loss=0.04 avg=0.09
# [429 | 1050.24] loss=0.04 avg=0.09
# [430 | 1052.58] loss=0.04 avg=0.09
# [431 | 1054.92] loss=0.03 avg=0.09
# [432 | 1057.27] loss=0.04 avg=0.09
# [433 | 1059.62] loss=0.04 avg=0.08
# [434 | 1061.97] loss=0.05 avg=0.08
# [435 | 1064.31] loss=0.04 avg=0.08
# [436 | 1066.66] loss=0.04 avg=0.08
# [499 | 1216.01] loss=0.05 avg=0.06
# [500 | 1218.41] loss=0.03 avg=0.06
# Saving checkpoint/run1/model-500
# Dawn,
# Morning; my boy, it's a-goin' ter
# o' Seth! It's a-goin' ter Seth! It's a-goin'
# itself ter Olaus Mueller, it comes a-goin' fer Seth! It comes a-goin' fer
# itself fer Seth! It comes a-goin' fer it, it comes a-goin'
# itself fer it, it comes a-it, it comes a-it, it comes a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it came a-it, it came a-it, it came a-it, it
# it went a-go, it went a-goin' fer it. An' it was a-ugly afresh.
#
# Mr. Hoadley's men lined the slope with ration, and rushed
# through the gates at the Cyclopean age. They beat the Indians with
# barking trunks, and berated the men who roamed the countryside
# with machine-gun fire. Two or three were shot dead, but the horror
# was gone. The natives, hushed, seemed at peace.
#
# "Gawd almighty, the thing that runtted up this morning--that madman
# with the red boots--was never told a single drop of blood."
#
# There was a pandemonium of questioning, and only Henry Wheeler thought
# to rescue the fallen telescope and wipe it clean of mud. Curtis was
# past all coherence, and even isolated replies were almost too much for
# him.
#
# "Bigger 'n a barn ... all made o' squirmin' ropes ... hull thing sort
# o' shaped like a hen's egg bigger'n anything, with dozens o' legs like
# hogsheads that haff shut up when they step ... nothin' solid abaout
# it--all like jelly, an' made o' sep'rit wrigglin' ropes pushed clost
# together ... great bulgin' eyes all over it ... ten or twenty maouths
# or trunks a-stickin' aout all along the sides, big as stovepipes, an'
# all a-tossin' an' openin' an' shuttin' ... all gray, with kinder blue
# or purple rings ... _an' Gawd in Heaven--that haff face on top_!..."
#
# This final memory, whatever it was, proved too much for poor Curtis,
# and he collapsed completely before he could say more. Fred Farr and
# Will Hutchins carried him to the roadside and laid him on the damp
# grass. Henry Wheeler, trembling, turned the rescued telescope on the
# mountain to see what he might. Through the lenses were discernible
# three tiny figures, apparently running toward the summit as fast as the
# steep incline allowed. Only these--nothing more. Then everyone noticed
# a strangely unseasonable noise in the deep valley behind, and even in
# the underbrush of Sentinel Hill itself. It was the piping of unnumbered
# whippoorwills, and in their shrill chorus there seemed to lurk a note
# of tense and evil expectancy.
#
# Earl Sawyer now took the telescope and reported the three figures as
# standing on the topmost ridge, virtually level with the altar-stone
# but at a considerable distance from it. One figure, he said, seemed
# to be raising its hands above its head at rhythmic intervals; and
# as Sawyer mentioned the circumstance the crowd seemed to hear a
# faint, half-musical sound from the distance, as if a loud chant
# were accompanying the gestures. The weird silhouette on that
# remote peak must have been a spectacle of infinite grotesqueness
# and impressiveness, but no observer was in a mood for esthetic
# appreciation. "I guess he's sayin' the spell," whispered Wheeler as
# he snatched back the telescope. The whippoorwills were piping wildly,
# and in a singularly curious irregular rhythm quite unlike that of the
# visible ritual.
#
# Suddenly the sunshine seemed to lessen without the intervention
